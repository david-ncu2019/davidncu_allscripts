# %%
from my_packages import *

# %%
df = pd.read_csv(r"E:\SUBSIDENCE_PROJECT_DATA\MLCW_QGIS_20241024\MLCWs_Files\MLCW_inCRFP.csv")
select_well = df["WellCode"].tolist()
df.head(5)
# Out:
#   WellCode        LAT        LONG   Z
# 0  MW_SJES  23.900000  120.310000   6
# 1  MW_SKES  23.860298  120.289506   3
# 2  MW_SHES  23.892061  120.394703  18
# 3  MW_SSES  23.937911  120.394274  14
# 4  MW_HNES  23.950000  120.480000  20

# %%
table = pd.read_table(r"E:\SUBSIDENCE_PROJECT_DATA\地陷資料整理\地陷井\select_MLCW_inCRFP.txt", sep=',')
table.query("LandSubsid	in @df['WellCode']")
# table["檔案名"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 table = pd.read_table(r"E:\SUBSIDENCE_PROJECT_DATA\地陷資料整理\地陷井\select_MLCW_inCRFP.txt", sep=',')
# ----> 2 table.query("LandSubsid	in @df['WellCode']")
#
# File D:\VENV_PYTHON\py3_8\lib\site-packages\pandas\core\frame.py:4111, in DataFrame.query(self, expr, inplace, **kwargs)
#    4109 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110 kwargs["target"] = None
# -> 4111 res = self.eval(expr, **kwargs)
#    4113 try:
#    4114     result = self.loc[res]
#
# File D:\VENV_PYTHON\py3_8\lib\site-packages\pandas\core\frame.py:4240, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4237     kwargs["target"] = self
#    4238 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4240 return _eval(expr, inplace=inplace, **kwargs)
#
# ...

# %%
fpath = r"D:\1000_SCRIPTS\001_PreQE_Scripts\MultiLayerCompactionMonitoringWells\MLCW_Data_Extraction\YL_WSYL23G1_TUKU_土庫.xlsx"
df = pd.read_excel(fpath)
df.head(5)
# Out:
#     TOP  BOTTOM  THICKNESS  SOIL_CATEGORY SOIL_TYPE IDENTIFIER
# 0   0.0     4.5        4.5              3      cSmS       S001
# 1   4.5     5.5        1.0              5         Z       S002
# 2   5.5     6.5        1.0              3      cSmS       S003
# 3   6.5    10.0        3.5              5         M       S004
# 4  10.0    23.0       13.0              3      cSmS       S005
