# %%
from appgeopy import *  # Another custom package, likely for geospatial processing
from my_packages import *  # Custom package containing specific functions

# %%
o_displacement_fpath = r"E:\030_CHOUSHUI_2024\000_INSCALDEFO_2_INSSTACKPSI\PROCESS_004\16_VALIDATION\LOS_output_002\CALIBRATED_oChoushui_DISPLACEMENT_LOS_mm.pkl"
o_displacement_geodf = pd.read_pickle(
    o_displacement_fpath, compression="zip"
).set_index("PointKey")

# %%
input_mfile = r"E:\030_CHOUSHUI_2024\000_INSCALDEFO_2_INSSTACKPSI\PROCESS_001\11_INSCALDEFO_inspsn\MFILE_INSCALDEFO_adjusted_deformations.txt"
mfile_datetimes = datetime_handle.extract_datetime_from_mfile(input_mfile)[1:]

# %%
select_pointkey_fpath = r"E:\030_CHOUSHUI_2024\000_INSCALDEFO_2_INSSTACKPSI\PROCESS_004\14_POST-PROCESSING\oChoushui_PSC_nearbyGPS_1000m.pkl"
select_pointkey = pd.read_pickle(
    select_pointkey_fpath, compression="zip"
)
