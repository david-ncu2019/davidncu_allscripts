# %%
from appgeopy import *

# %%
stations = gpd.read_file(r"./sample_shapefiles/stations.shp")
points = gpd.read_file(r"./sample_shapefiles/points.shp")

# %%
select_station = stations.loc[0]
select_station["NAME"]
# Out:
# 'FIRST'

# %%
geospatial.find_point_neighbors(stations.iloc[1, :], points, "NAME", 0.01)
# Out:
#     Id                    geometry    NAME
# 8    9  POINT (120.41579 23.85466)  SECOND
# 9   10  POINT (120.42035 23.85181)  SECOND
# 10  11  POINT (120.41897 23.85370)  SECOND
