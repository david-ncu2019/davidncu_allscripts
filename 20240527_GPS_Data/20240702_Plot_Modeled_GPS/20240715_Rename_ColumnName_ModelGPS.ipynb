# %%
from appgeopy import *
from my_packages import *

# %%
topfolder = r"E:\SUBSIDENCE_PROJECT_DATA\GPS_2023_YehDaGang\2023_NEW_20240515\20240527_PROCESSED_DATA\_MERGED\6__Difference_Modeled"
filename = "Modeled_GPS_Differences_LOS_mm_2022_2023_v1.xlsx"

savename = "Modeled_GPS_Differences_LOS_mm_2022_2023_v2.xlsx"
savepath = os.path.join(topfolder, savename)

fpath = os.path.join(topfolder, filename)

available_sheetnames = data_io.get_sheetnames(fpath)

colname_to_change = ["Datetime", "N(mm)", "E(mm)", "h(mm)", "LOS(mm)"]

# select_sheet = available_sheetnames[0]
for select_sheet in tqdm(available_sheetnames):

    df = pd.read_excel(fpath, sheet_name=select_sheet)

    df.columns = colname_to_change

    data_io.save_df_to_excel(df_to_save=df, filepath=savepath, sheet_name=select_sheet, verbose=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 51/51 [00:17<00:00,  2.93it/s]
