# %%
from appgeopy import *
from my_packages import *

# %%
# backtransform_disp_df = pd.read_pickle(
#     r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\2_KrigingInterpolation\5_PostKriging\PostKriging_Backtransform_Data\grid_points\BACKTRANSFORMED_Monthly_DISPLACEMENT_dU_CRFP_Full.xz"
# )

# backtransform_disp_df = pd.read_pickle(
#     r"D:\1000_SCRIPTS\003_Project002\20250917_GTWR002\2_KrigingInterpolation\5_PostKriging\PostKriging_Backtransform_Data\grid_points\BACKTRANSFORMED_Monthly_DISPLACEMENT_dU_CRFP_2025_Full.xz"
# )

backtransform_disp_df = pd.read_pickle(
    r"D:\1000_SCRIPTS\003_Project002\20250917_GTWR002\2_KrigingInterpolation\5_PostKriging\PostKriging_Backtransform_Data\BACKTRANSFORMED_CORRECTED_Monthly_DISPLACEMENT_CRFP_saveqgis_Oct2025_grid_grid.xz"
)

# convert InSAR backtransformed disp to cumdisp
disp_info_df = backtransform_disp_df.iloc[:, :3]
disp_measure = backtransform_disp_df.iloc[:, 3:]

backtransform_cumdisp_df = pd.concat(
    [disp_info_df, disp_measure.cumsum(axis=1)], axis=1
)

measure_cols = [
    col for col in backtransform_cumdisp_df.columns if col.startswith("D")
]

show(backtransform_cumdisp_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_cefccdb5_113a_45ad_8410_a31f66f7e14c"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.5 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_cefccdb5_113a_45ad_8410_a31f66f7e14c:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "order": [], "text_in_header_can_be_selected": true, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 907,462x114 to 90x90 as maxBytes=64KB", "filtered_row_count": 907372, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>X_TWD97</th>\n      <th>Y_TWD97</th>\n      <th>D20160430</th>\n      <th>D20160531</th>\n      <th>D20160630</th>\n      <th>D20160731</th>\n      <th>D20160831</th>\n      <th>D20160930</th>\n      <th>D20161031</th>\n      <th>D20161130</th>\n      <th>D20161231</th>\n      <th>D20170131</th>\n      <th>D20170228</th>\n      <th>D20170331</th>\n      <th>D20170430</th>\n      <th>D20170531</th>\n      <th>D20170630</th>\n      <th>D20170731</th>\n      <th>D20170831</th>\n      <th>D20170930</th>\n      <th>D20171031</th>\n      <th>D20171130</th>\n      <th>D20171231</th>\n      <th>D20180131</th>\n      <th>D20180228</th>\n      <th>D20180331</th>\n      <th>D20180430</th>\n      <th>D20180531</th>\n      <th>D20180630</th>\n      <th>D20180731</th>\n      <th>D20180831</th>\n      <th>D20180930</th>\n      <th>D20181031</th>\n      <th>D20181130</th>\n      <th>D20181231</th>\n      <th>D20190131</th>\n      <th>D20190228</th>\n      <th>D20190331</th>\n      <th>D20190430</th>\n      <th>D20190531</th>\n      <th>D20190630</th>\n      <th>D20190731</th>\n      <th>D20190831</th>\n      <th>D20190930</th>\n      <th>D20191031</th>\n      <th>D20211130</th>\n      <th>D20211231</th>\n      <th>D20220131</th>\n      <th>D20220228</th>\n      <th>D20220331</th>\n      <th>D20220430</th>\n      <th>D20220531</th>\n      <th>D20220630</th>\n      <th>D20220731</th>\n      <th>D20220831</th>\n      <th>D20220930</th>\n      <th>D20221031</th>\n      <th>D20221130</th>\n      <th>D20221231</th>\n      <th>D20230131</th>\n      <th>D20230228</th>\n      <th>D20230331</th>\n      <th>D20230430</th>\n      <th>D20230531</th>\n      <th>D20230630</th>\n      <th>D20230731</th>\n      <th>D20230831</th>\n      <th>D20230930</th>\n      <th>D20231031</th>\n      <th>D20231130</th>\n      <th>D20231231</th>\n      <th>D20240131</th>\n      <th>D20240229</th>\n      <th>D20240331</th>\n      <th>D20240430</th>\n      <th>D20240531</th>\n      <th>D20240630</th>\n      <th>D20240731</th>\n      <th>D20240831</th>\n      <th>D20240930</th>\n      <th>D20241031</th>\n      <th>D20241130</th>\n      <th>D20241231</th>\n      <th>D20250131</th>\n      <th>D20250228</th>\n      <th>D20250331</th>\n      <th>D20250430</th>\n      <th>D20250531</th>\n      <th>D20250630</th>\n      <th>D20250731</th>\n    </tr>\n    <tr>\n      <th>PointKey</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      ...

# %%
# regpoints_files = glob(os.path.join("regpoints_filefld", "*.feather"))

feather_file_fld = "regpoints_Chunk100"
chunksize = 100

regpoints_files = glob(os.path.join(os.getcwd(), feather_file_fld, "*.feather"))

predictor_colname = "CUMDISP"
output_fld = feather_file_fld + f"_add{predictor_colname}"

if not os.path.exists(output_fld):
    os.makedirs(output_fld, exist_ok=True)

# select_file = regpoints_files[0]
for select_file in tqdm(regpoints_files[:1]):

    basename = os.path.basename(select_file)
    savepath = os.path.join(output_fld, basename)

    df = pd.read_feather(select_file)
    df = df.set_index("PointKey")

    monthly_intervals = df["monthly"].unique()

    updated_df = pd.DataFrame(data=None, index=None)

    # idx = 0
    for idx in trange(len(monthly_intervals), position=1, leave=False):
        current_month_interval = monthly_intervals[idx]

        df_byTimePeriod = df.query("monthly==@current_month_interval")

        df_byTimePeriod["CUMDISP"] = df_byTimePeriod.index.map(
            backtransform_cumdisp_df.loc[:, measure_cols[idx]]
        )

        updated_df = pd.concat([updated_df, df_byTimePeriod])

    # updated_df.reset_index(drop=False)
    # updated_df.to_feather(savepath)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]

# %%
df
# Out:
#                              X_TWD97       Y_TWD97  monthly
# PointKey
# X162648119Y2595992857  162648.119363  2.595993e+06        1
# X162848119Y2595992857  162848.119363  2.595993e+06        1
# X163048119Y2595992857  163048.119363  2.595993e+06        1
# X162648119Y2596192857  162648.119363  2.596193e+06        1
# X162848119Y2596192857  162848.119363  2.596193e+06        1
# ...                              ...           ...      ...
# X167648119Y2597192857  167648.119363  2.597193e+06       67
# X167848119Y2597192857  167848.119363  2.597193e+06       67
# X163448119Y2597392857  163448.119363  2.597393e+06       67
# X163648119Y2597392857  163648.119363  2.597393e+06       67
# X163848119Y2597392857  163848.119363  2.597393e+06       67
#
# [6700 rows x 3 columns]
