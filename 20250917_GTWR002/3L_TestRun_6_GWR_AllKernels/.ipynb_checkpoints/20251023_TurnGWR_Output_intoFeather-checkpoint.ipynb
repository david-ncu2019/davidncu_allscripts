# %%
from appgeopy import *
from my_packages import *

# %% [raw]
# fpath = r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\6_GWR\3_TestRun_003\GWR_Prediction_Output\Layer_1.feather"
# df = pd.read_feather(fpath)
# show(df)

# %%
mainfld = r".\GWR_Prediction_Output"

subflds = glob(os.path.join(mainfld, "Layer*"))
subflds
# Out:
# ['.\\GWR_Prediction_Output\\Layer_1',
#  '.\\GWR_Prediction_Output\\Layer_2',
#  '.\\GWR_Prediction_Output\\Layer_3',
#  '.\\GWR_Prediction_Output\\Layer_4']

# %%
# select_fld = subflds[0]
for select_fld in subflds[:]:

    base = os.path.basename(select_fld)

    files_byFolder = sorted(
        glob(os.path.join(select_fld, "GWR_prediction*results.csv"))
    )

    output_combine = pd.concat(
        [pd.read_csv(f) for f in tqdm(files_byFolder)], ignore_index=True
    )

    output_combine = output_combine.iloc[:, :-2]
    output_combine["prediction_std"] = np.sqrt(output_combine["prediction_var"])

    output_combine = output_combine.sort_values(by="monthly")

    output_combine.to_feather(os.path.join(mainfld, f"GWR_{base}.feather"))
# Out:
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]

# %%
output_combine
# Out:
#                X_TWD97       Y_TWD97  monthly datetime_str  DIFFDISP  \
# 1353846  166048.119363  2.618393e+06        1    N20160501 -0.700000
# 1362689  177848.119363  2.626793e+06        1    N20160501 -1.310000
# 1362690  178048.119363  2.626793e+06        1    N20160501 -1.470000
# 1362691  178248.119363  2.626793e+06        1    N20160501 -0.380000
# 1362692  190048.119363  2.622993e+06        1    N20160501  5.760000
# ...                ...           ...      ...          ...       ...
# 513221   200048.119363  2.667193e+06       67    N20211101  1.339689
# 513220   200248.119363  2.667193e+06       67    N20211101  0.836930
# 513219   200448.119363  2.667193e+06       67    N20211101  0.607316
# 513229   200848.119363  2.667193e+06       67    N20211101  1.128789
# 477830   199848.119363  2.673993e+06       67    N20211101 -0.709507
#
#          Intercept_coef  DIFFDISP_coef  prediction  prediction_var  \
# 1353846       -0.454140       0.024840   -0.471528        1.067627
# 1362689       -0.782507      -0.015392   -0.762343        1.045159
# 1362690       -0.789130      -0.016054   -0.765530        1.040792
# 1362691       -0.795875      -0.016725   -0.789520        1.076188
# 1362692       -0.625591       0.012596   -0.553039        1.305768
# ...                 ...            ...         ...             ...
# 513221         0.795060       0.236359    1.111708        2.661858
# 513220         0.795349       0.236396    0.993196        2.458027
# 513219         0.795609       0.236424    0.939194        2.374042
# 513229         0.796048       0.236455    1.062956        2.570650
# 477830         0.794572       0.231928    0.630018        2.015809
#
#          prediction_std
# 1353846        1.033261
# 1362689        1.022330
# 1362690        1.020192
# 1362691        1.037395
# 1362692        1.142702
# ...                 ...
# 513221         1.631520
# 513220         1.567810
# 513219         1.540792
# 513229         1.603325
# 477830         1.419792
#
# [3557164 rows x 10 columns]
