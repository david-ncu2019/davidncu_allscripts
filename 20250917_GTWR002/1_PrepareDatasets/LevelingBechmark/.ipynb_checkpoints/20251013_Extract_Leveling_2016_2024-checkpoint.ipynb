# %%
from appgeopy import *
from my_packages import *

# %%
fpath = r"E:\SUBSIDENCE_PROJECT_DATA\LevelingSurvey\附錄6-水準測量檢測成果\Changhua_Leveling_2024_modified.xlsx"
base = os.path.basename(fpath)

df = pd.read_excel(fpath)

df = df.set_index("ALTCODE")

info_cols = [col for col in df.columns if not col.startswith("N")]
datetime_cols = [col for col in df.columns if col.startswith("N")]

show(df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_80be256e_b431_4c89_8107_3998be077a45"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.5 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_80be256e_b431_4c89_8107_3998be077a45:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "order": [], "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 516x32 to 256x32 as maxBytes=64KB", "filtered_row_count": 260, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>CODE</th>\n      <th>X_TWD97</th>\n      <th>Y_TWD97</th>\n      <th>N19921001</th>\n      <th>N19930801</th>\n      <th>N19950801</th>\n      <th>N19970801</th>\n      <th>N19980801</th>\n      <th>N20000601</th>\n      <th>N20010801</th>\n      <th>N20030801</th>\n      <th>N20040801</th>\n      <th>N20050501</th>\n      <th>N20061001</th>\n      <th>N20070701</th>\n      <th>N20080601</th>\n      <th>N20090701</th>\n      <th>N20100601</th>\n      <th>N20110601</th>\n      <th>N20120601</th>\n      <th>N20130601</th>\n      <th>N20140601</th>\n      <th>N20150601</th>\n      <th>N20160501</th>\n      <th>N20170501</th>\n      <th>N20180501</th>\n      <th>N20190501</th>\n      <th>N20200501</th>\n      <th>N20210501</th>\n      <th>N20220501</th>\n      <th>N20230501</th>\n      <th>N20240501</th>\n    </tr>\n    <tr>\n      <th>ALTCODE</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"CHBM11\", \"BM11\", 195028.0, 2660223.0, 6.6483, 6.6603, 6.6627, 6.6417, 6.6126, 6.6092, 6.68584, 6.65232, 6.65226, 6.64587, 6.64546, 6.64688, 6.6319, 6.63743, 6.63667, 6.63199, 6.63503, 6.64181, \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\"], [\"CHBM12\", \"BM12\", 194810.0, 2663106.0, 5.3096, 5.3397, 5.3238, 5.3116, 5.2901, 5.3553, 5.34355, 5.32317, 5.32257, 5.32037, 5.31929, 5.32222, 5.31334, 5.31219, 5.31517, 5.31731, 5.31576, 5.32304, 5.31707, 5.30999, 5.31572, 5.31492, 5.31053, 5.31035, 5.30865, 5.30176, 5.3062, 5.31363, 5.30977], [\"CHBM15\", \"BM15\", 191603.0, 2643480.0, \"___NaN___\", \"___NaN___\", 18.5951, 18.5293, 18.477, 18.4368, 18.36388, 18.21155, 18.12957, 18.07822, 18.00187, 17.96803, 17.9221, 17.88192, 17.84196, 17.80818, 17.77441, 17.75577, 17.73251, 17.70708, 17.69187, 17.6684, \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\"], [\"CHBM16\", \"BM16\", 178967.0, 2637431.0, \"___NaN___\", \"___NaN___\", 7.2254, 6.7536, 6.5684, 6.4075, 6.23969, 6.08547, 6.00881, 5.94767, 5.88407, 5.84972, 5.82247, 5.82622, 5.81731, 5.81456, 5.81071, 5.82579, 5.81899, 5.8019, 5.81616, 5.80225, 5.78672, 5.78895, 5.77799, 5.75344, 5.77715, 5.76223, 5.76269], [\"CHBM17\", \"BM17\", 180795.0, 2638844.0, \"___NaN___\", 9.4046, 9.0344, 8.6008, 8.4124, 8.1888, 8.01271, 7.81444, 7.71669, 7.6432, 7.56217, 7.52109, 7.48645, 7.48451, 7.47233, 7.4657, 7.46495, 7.47829, 7.46698, 7.45278, 7.46279, 7.44796, 7.43491, 7.43677, 7.42549, 7.40707, 7.4277, 7.41619, 7.41358], [\"CHBM19\", \"BM19\", 179943.0, 2644352.0, \"___NaN___\", \"___NaN___\", 5.6909, 5.5133, 5.4109, 5.3045, 5.15951, 5.00144, 4.92021, 4.8518, 4.75711, 4.71023, 4.67257, 4.66629, 4.65731, 4.65378, 4.64919, 4.65895, 4.65047, 4.64203, 4.64685, \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"___NaN___\", \"_ ...

# %%
measure_df = df.loc[:, datetime_cols]
# measure_df.columns = pd.to_datetime([col[1:] for col in measure_df.columns])

temp = measure_df.loc[:, "N2015":]

# Drop rows where first or last column is NaN
temp = temp.dropna(subset=[temp.columns[0], temp.columns[-1]])

# Then drop rows with fewer than 4 non-NaN values (considering all columns)
temp = temp.dropna(thresh=4)

info_df = df.loc[:, info_cols]
temp = pd.concat([info_df.loc[temp.index, :], temp], axis=1)

temp.to_pickle(base.replace(".xlsx", "2016_2024.xz"))

# %%
gdf = geospatial.convert_to_geodata(
    df=temp, xcoord_col="X_TWD97", ycoord_col="Y_TWD97", crs_epsg="EPSG:3826"
)
gdf.to_file(base.replace(".xlsx", ".shp"))
