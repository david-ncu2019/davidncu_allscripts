# %% [markdown]
# 1. Open file containing timeseries of cumulative displacement
# 2. Open file containing leveling measurement of county ABC
# 3. Open file containing `PointKey` of points surrounding the leveling benchmark in county ABC
# 4. Loop through each benchmark, select `PointKey` of points surrounding that benchmark.
# 5. Take average of the `CUMDISP` timeseries of those points
# 6. Calculate linear trend (force zero intercept) of leveling measurement and `CUMDISP`
# 7. Calculate the difference $\Delta slope = slope_{Leveling} - slope_{InSAR}$
# 8. Export the final table with `coordinates` and $\Delta slope$

# %%
from appgeopy import *
from my_packages import *

# %%
def get_slope(input_series, force=True):
    fulltime_arr = datetime_handle.get_fulltime(input_series.index)
    fulltime_timeseries = datetime_handle.fulltime_table(
        df=input_series, fulltime_series=fulltime_arr
    )
    linear_trend, slope = analysis.get_linear_trend(
        series=fulltime_timeseries, force_zero_intercept=force
    )
    return linear_trend, slope

# %%
# load timeseries of cumulative displacement of all points
cumdisp_df = pd.read_pickle(
    r"D:\1000_SCRIPTS\003_Project002\20250917_GTWR002\2_KrigingInterpolation\5_PostKriging\Monthly_CUMDISP_saveqgis_Oct2025.xz"
)
cumdisp_df = cumdisp_df.set_index("PointKey")
show(cumdisp_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_fad04add_d4e1_4132_baa4_85cd6cb6db97"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.5 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_fad04add_d4e1_4132_baa4_85cd6cb6db97:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 1,478,460x114 to 90x90 as maxBytes=64KB", "filtered_row_count": 1478370, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>X_TWD97</th>\n      <th>Y_TWD97</th>\n      <th>D20160430</th>\n      <th>D20160531</th>\n      <th>D20160630</th>\n      <th>D20160731</th>\n      <th>D20160831</th>\n      <th>D20160930</th>\n      <th>D20161031</th>\n      <th>D20161130</th>\n      <th>D20161231</th>\n      <th>D20170131</th>\n      <th>D20170228</th>\n      <th>D20170331</th>\n      <th>D20170430</th>\n      <th>D20170531</th>\n      <th>D20170630</th>\n      <th>D20170731</th>\n      <th>D20170831</th>\n      <th>D20170930</th>\n      <th>D20171031</th>\n      <th>D20171130</th>\n      <th>D20171231</th>\n      <th>D20180131</th>\n      <th>D20180228</th>\n      <th>D20180331</th>\n      <th>D20180430</th>\n      <th>D20180531</th>\n      <th>D20180630</th>\n      <th>D20180731</th>\n      <th>D20180831</th>\n      <th>D20180930</th>\n      <th>D20181031</th>\n      <th>D20181130</th>\n      <th>D20181231</th>\n      <th>D20190131</th>\n      <th>D20190228</th>\n      <th>D20190331</th>\n      <th>D20190430</th>\n      <th>D20190531</th>\n      <th>D20190630</th>\n      <th>D20190731</th>\n      <th>D20190831</th>\n      <th>D20190930</th>\n      <th>D20191031</th>\n      <th>D20211130</th>\n      <th>D20211231</th>\n      <th>D20220131</th>\n      <th>D20220228</th>\n      <th>D20220331</th>\n      <th>D20220430</th>\n      <th>D20220531</th>\n      <th>D20220630</th>\n      <th>D20220731</th>\n      <th>D20220831</th>\n      <th>D20220930</th>\n      <th>D20221031</th>\n      <th>D20221130</th>\n      <th>D20221231</th>\n      <th>D20230131</th>\n      <th>D20230228</th>\n      <th>D20230331</th>\n      <th>D20230430</th>\n      <th>D20230531</th>\n      <th>D20230630</th>\n      <th>D20230731</th>\n      <th>D20230831</th>\n      <th>D20230930</th>\n      <th>D20231031</th>\n      <th>D20231130</th>\n      <th>D20231231</th>\n      <th>D20240131</th>\n      <th>D20240229</th>\n      <th>D20240331</th>\n      <th>D20240430</th>\n      <th>D20240531</th>\n      <th>D20240630</th>\n      <th>D20240731</th>\n      <th>D20240831</th>\n      <th>D20240930</th>\n      <th>D20241031</th>\n      <th>D20241130</th>\n      <th>D20241231</th>\n      <th>D20250131</th>\n      <th>D20250228</th>\n      <th>D20250331</th>\n      <th>D20250430</th>\n      <th>D20250531</th>\n      <th>D20250630</th>\n      <th>D20250731</th>\n    </tr>\n    <tr>\n      <th>PointKey</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n   ...

# %%
leveling_fpath = r"Yunlin_Leveling_2024_modified2016_2024.xz"
leveling_df = pd.read_pickle(leveling_fpath)
show(leveling_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_8c728c75_375b_476d_bdf6_b51b96afa07e"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.5 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_8c728c75_375b_476d_bdf6_b51b96afa07e:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>CODE</th>\n      <th>X_TWD97</th>\n      <th>Y_TWD97</th>\n      <th>N20160501</th>\n      <th>N20170501</th>\n      <th>N20180501</th>\n      <th>N20190501</th>\n      <th>N20200501</th>\n      <th>N20210501</th>\n      <th>N20220501</th>\n      <th>N20230501</th>\n      <th>N20240501</th>\n    </tr>\n    <tr>\n      <th>ALTCODE</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"CHBM12\", \"BM12\", 194810.0, 2663106.0, 5.31572, 5.31492, 5.31053, 5.31035, 5.30865, 5.30176, 5.3062, 5.31363, 5.30977], [\"CHBM16\", \"BM16\", 178967.0, 2637431.0, 5.81616, 5.80225, 5.78672, 5.78895, 5.77799, 5.75344, 5.77715, 5.76223, 5.76269], [\"CHBM17\", \"BM17\", 180795.0, 2638844.0, 7.46279, 7.44796, 7.43491, 7.43677, 7.42549, 7.40707, 7.4277, 7.41619, 7.41358], [\"CHBM2\", \"BM2\", 183061.0, 2641384.0, 9.80521, 9.79163, 9.77632, 9.76823, 9.75664, 9.73927, 9.74043, 9.72791, 9.72491], [\"CHBM21\", \"BM21\", 187455.0, 2655865.0, 3.89501, 3.88352, 3.87298, 3.87056, 3.86452, 3.85442, 3.8602, 3.85557, 3.85344], [\"CHBM7\", \"BM7\", 185699.0, 2649081.0, 7.52849, 7.50927, 7.4914, 7.47886, 7.46352, 7.44758, 7.44422, 7.42927, 7.42578], [\"BMNO04\", \"BMNo04\", 208063.0, 2643389.0, 38.91657, 38.91581, 38.91551, 38.91693, 38.91321, 38.91079, 38.91467, 38.90835, 38.90154], [\"BMNO05\", \"BMNo05\", 203083.0, 2657964.0, 14.77836, 14.77486, 14.77062, 14.76754, 14.76178, 14.75643, 14.75931, 14.75001, 14.75064], [\"SJ0+300\", \"\\u65b0\\u8857\\u6d77\\u58240+300\", 179894.0, 2646367.0, 5.79686, 5.78748, 5.78148, 5.78119, 5.77409
M12\"], [\"X195001867Y2663110078\", 195001.867326, 2663110.0, \"CHBM12\"], [\"X194641766Y2663080205\", 194641.766923, 2663080.0, \"CHBM12\"], [\"X194681330Y2663079206\", 194681.330427, 2663079.0, \"CHBM12\"], [\"X194720893Y2663077997\", 194720.893117, 2663078.0, \"CHBM12\"], [\"X194761231Y2663076785\", 194761.23163, 2663077.0, \"CHBM12\"], [\"X194800795Y2663075787\", 194800.795144, 2663076.0, \"CHBM12\"], [\"X194841133Y2663074575\", 194841.133665, 2663075.0, \"CHBM12\"], [\"X194880696Y2663073366\", 194880.69637, 2663073.0, \"CHBM12\"], [\"X194921 ...

# %%
cache = {"ALTCODE": [], "Lev_slope": [], "InSAR_slope": [], "Delta_slope": []}

all_leveling_code = points_byLeveling["ALTCODE"].unique().tolist()

# loop through each leveling benchmark code
# select_leveling_code = all_leveling_code[0]

for select_leveling_code in tqdm(all_leveling_code):

    cache["ALTCODE"].append(select_leveling_code)

    # using the select benchmark code, we get the pointkey located within the leveling's buffer
    pointkey_byCode = points_byLeveling.query("ALTCODE==@select_leveling_code")[
        "PointKey"
    ].tolist()

    # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    # deal with Leveling survey timeseries
    # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

    leveling_measure_cols = [
        col for col in leveling_df.columns if col.startswith("N")
    ]
    leveling_timeseries = leveling_df.loc[
        select_leveling_code, leveling_measure_cols
    ]

    leveling_timeseries = leveling_timeseries.astype(np.float64)
    # reference the measurement to the first acquisition
    # and convert to milimeter
    leveling_timeseries = (
        leveling_timeseries - leveling_timeseries.iloc[0]
    ) * 1000

    leveling_timeseries.index = pd.to_datetime(
        [idx[1:] for idx in leveling_timeseries.index]
    )

    # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    # deal with CUMDISP timeseries
    # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

    cumdisp_byLevelingCode = cumdisp_df.loc[pointkey_byCode, :]

    cumdisp_measure_cols = [
        col for col in cumdisp_byLevelingCode.columns if col.startswith("D")
    ]

    cumdisp_byLevelingCode = cumdisp_byLevelingCode.loc[:, cumdisp_measure_cols]

    average_cumdisp_byLevelingCode = cumdisp_byLevelingCode.mean(axis=0)

    # we add one day to convert datetime to the beginning of the month
    average_cumdisp_byLevelingCode.index = [
        pd.to_datetime(idx[1:]) + relativedelta(days=1)
        for idx in average_cumdisp_byLevelingCode.index
    ]

    #### do not need to reference to the first date

    # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    # calculate slope value for each
    # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

    # leveling timeseries
    leveling_trend, leveling_slope = get_slope(leveling_timeseries)

    # average cumdisp timeseries
    cumdisp_trend, cumdisp_slope = get_slope(
        average_cumdisp_byLevelingCode, force=False
    )

    # get slope difference
    delta_slope = leveling_slope - cumdisp_slope

    # Add information to dictionary for later saving
    cache["Lev_slope"].append(leveling_slope)
    cache["InSAR_slope"].append(cumdisp_slope)
    cache["Delta_slope"].append(delta_slope)
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]

# %%
output_df = pd.DataFrame(cache)
output_df = output_df.set_index("ALTCODE")
for col in ["X_TWD97", "Y_TWD97"]:
    output_df[col] = output_df.index.map(leveling_df[col])

output_df.to_pickle(leveling_fpath.replace(".xz", "_deltaSlope.xz"))
