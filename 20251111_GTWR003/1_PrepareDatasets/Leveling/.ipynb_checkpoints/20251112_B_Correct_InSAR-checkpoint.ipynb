# %%
from appgeopy import *
from my_packages import *

# %% [markdown]
# #### First step
#
# We need to perform Kriging to interpolate the delta slope to InSAR points

# %% [markdown]
# #### Add back the slope-based correction into original InSAR

# %%
delta_slope_fpath = (
    r"D:\1000_SCRIPTS\003_Project002\20251111_GTWR003\20251111_LevelingWork.gdb"
)

delta_slope_df = gpd.read_file(
    delta_slope_fpath,
    read_geometry=False,
    layer="DeltaSlope_ChangYunChia_Oct2025",
)
delta_slope_df = delta_slope_df.set_index("PointKey")
delta_slope_df = delta_slope_df.sort_index()
show(delta_slope_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_95bc83e4_923d_4bdf_9a1f_0973d9b5dfe4"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.5 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_95bc83e4_923d_4bdf_9a1f_0973d9b5dfe4:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 1,095,487x5 to 1,638x5 as maxBytes=64KB", "filtered_row_count": 1093849, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>X_TWD97</th>\n      <th>Y_TWD97</th>\n      <th>Included</th>\n      <th>Predicted</th>\n      <th>StdError</th>\n    </tr>\n    <tr>\n      <th>PointKey</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"X161701940Y2594931653\", 161701.94041, 2594932.0, \"Yes\", -0.084899, 0.013188], [\"X161738005Y2601967325\", 161738.005075, 2601967.0, \"Yes\", -0.067701, 0.012785], [\"X161772290Y2613200957\", 161772.290641, 2613201.0, \"Yes\", -0.056712, 0.012241], [\"X161811991Y2613199872\", 161811.99158, 2613200.0, \"Yes\", -0.056736, 0.012206], [\"X161821971Y2594928398\", 161821.97155, 2594928.0, \"Yes\", -0.08515, 0.013034], [\"X161851691Y2613198576\", 161851.691245, 2613199.0, \"Yes\", -0.056761, 0.012171], [\"X161878376Y2612718251\", 161878.376623, 2612718.0, \"Yes\", -0.05701, 0.012199], [\"X161891392Y2613197491\", 161891.392189, 2613197.0, \"Yes\", -0.057139, 0.01215], [\"X161897396Y2594766345\", 161897.396604, 2594766.0, \"Yes\", -0.085258, 0.013063], [\"X161898415Y2594806264\", 161898.415297, 2594806.0, \"Yes\", -0.085278, 0.013029], [\"X161899433Y2594846183\", 161899.433989, 2594846.0, \"Yes\", -0.085296, 0.012995], [\"X161900452Y2594886101\", 161900.452681, 2594886.0, \"Yes\", -0.085313, 0.012961], [\"X161901471Y2594926020\", 161901.471372, 2594926.0, \"Yes\", -0.085328, 0.012926], [\"X161902491Y2594966150\", 161902.491328, 2594966.0, \"Yes\", -0.085341, 0.012892], [\"X161918077Y2612716955\", 161918.077599, 2612717.0, \"Yes\", -0.057029, 0.012166], [\"X161931871Y2613196402\", 161931.871685, 2613196.0, \"Yes\", -0.057162, 0.012113], [\"X161937147Y2594765262\", 161937.147583, 2594765.0, \"Yes\", -0.085346, 0.013011], [\"X161938166Y2594805181\", 161938.166168, 2594805.0, \"Yes\", -0.085367, 0.012976], [\"X161939184Y2594845099\", 161939.184753, 2594845.0, \"Yes\", -0.085386, 0.012941], [\"X161940203Y2594885018\", 161940.203336, 2594885.0, \"Yes\", -0.085404, 0.012906], [\"X161941221Y2594924937\", 161941.221919, 2594925.0, \"Yes\", -0.08542, 0.01287], [\"X161943020Y2594964851\", 161943.020021, 2594965.0, \"Yes\", -0.085436, 0.012833], [\"X161944039Y2595004981\", 161944.039865, 2595005.0, \"Yes\", -0.085449, 0.012798], [\"X161967493Y2613035428\", 161967.493677, 2613035.0, \"Yes\", -0.057239, 0.012103], [\"X161968514Y2613075559\", 161968.514373, 2613076.0, \"Yes\", -0.057226, 0.012096], [\"X161972592Y2613235237\", 161972.59205, 2613235.0, \"Yes\", -0.05717, 0.012067], [\"X161973611Y2613275157\", 161973.611467, 2613275.0, \"Yes\", -0.057154, 0.012059], [\"X161976898Y2594764179\", 161976.898564, 2594764.0, \"Yes\", -0.085437, 0.012958], [\"X161977917Y2594804098\", 161977.917041, 2594804.0, \"Yes\", -0.085459, 0.012922], [\"X161978935Y2594844017\", 161978.935517, 2594844.0, \"Yes\", -0.085479, 0.012886], [\"X161980733Y2594883931\", 161980.733517, 2594884.0, \"Yes\", -0.0855, 0.012848], [\"X161981751Y2594923849\", 161981.75199, 2594924.0, \"Yes\", -0.085517, 0.012811], [\"X161982770Y2594963768\", 161982.770462, 2594964.0, \"Yes\", -0.085532, 0.012775], [\"X161983788Y2595003687\", 161983.788933, 2595004.0, \"Yes\", -0.085546, 0.012738], [\"X161998260Y2612714781\", 161998.260683, 2612715.0, \"Yes\", -0.057644, 0.01211], [\"X162007195Y2613034344\", 162007.195062, 2613034.0, \"Yes\", -0.057261, 0.012066], [\"X162013071Y2613234148\", 162013.071438, 2613234.0, \"Yes\", -0.057196, ...

# %%
# load timeseries of cumulative displacement of all points
cumdisp_df = pd.read_pickle(r"Monthly_CUMDISP_saveqgis_Oct2025.xz")

mutual_pointkey = sorted(
    set(cumdisp_df["PointKey"].unique()).intersection(set(delta_slope_df.index))
)

cumdisp_df = cumdisp_df.set_index("PointKey")
cumdisp_df = cumdisp_df.loc[mutual_pointkey, :]
cumdisp_df = cumdisp_df.sort_index()
show(cumdisp_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_c33629e6_9d6e_45cf_a207_ad6a7d767a7f"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.5 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_c33629e6_9d6e_45cf_a207_ad6a7d767a7f:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 1,095,487x114 to 90x90 as maxBytes=64KB", "filtered_row_count": 1095397, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>X_TWD97</th>\n      <th>Y_TWD97</th>\n      <th>D20160430</th>\n      <th>D20160531</th>\n      <th>D20160630</th>\n      <th>D20160731</th>\n      <th>D20160831</th>\n      <th>D20160930</th>\n      <th>D20161031</th>\n      <th>D20161130</th>\n      <th>D20161231</th>\n      <th>D20170131</th>\n      <th>D20170228</th>\n      <th>D20170331</th>\n      <th>D20170430</th>\n      <th>D20170531</th>\n      <th>D20170630</th>\n      <th>D20170731</th>\n      <th>D20170831</th>\n      <th>D20170930</th>\n      <th>D20171031</th>\n      <th>D20171130</th>\n      <th>D20171231</th>\n      <th>D20180131</th>\n      <th>D20180228</th>\n      <th>D20180331</th>\n      <th>D20180430</th>\n      <th>D20180531</th>\n      <th>D20180630</th>\n      <th>D20180731</th>\n      <th>D20180831</th>\n      <th>D20180930</th>\n      <th>D20181031</th>\n      <th>D20181130</th>\n      <th>D20181231</th>\n      <th>D20190131</th>\n      <th>D20190228</th>\n      <th>D20190331</th>\n      <th>D20190430</th>\n      <th>D20190531</th>\n      <th>D20190630</th>\n      <th>D20190731</th>\n      <th>D20190831</th>\n      <th>D20190930</th>\n      <th>D20191031</th>\n      <th>D20211130</th>\n      <th>D20211231</th>\n      <th>D20220131</th>\n      <th>D20220228</th>\n      <th>D20220331</th>\n      <th>D20220430</th>\n      <th>D20220531</th>\n      <th>D20220630</th>\n      <th>D20220731</th>\n      <th>D20220831</th>\n      <th>D20220930</th>\n      <th>D20221031</th>\n      <th>D20221130</th>\n      <th>D20221231</th>\n      <th>D20230131</th>\n      <th>D20230228</th>\n      <th>D20230331</th>\n      <th>D20230430</th>\n      <th>D20230531</th>\n      <th>D20230630</th>\n      <th>D20230731</th>\n      <th>D20230831</th>\n      <th>D20230930</th>\n      <th>D20231031</th>\n      <th>D20231130</th>\n      <th>D20231231</th>\n      <th>D20240131</th>\n      <th>D20240229</th>\n      <th>D20240331</th>\n      <th>D20240430</th>\n      <th>D20240531</th>\n      <th>D20240630</th>\n      <th>D20240731</th>\n      <th>D20240831</th>\n      <th>D20240930</th>\n      <th>D20241031</th>\n      <th>D20241130</th>\n      <th>D20241231</th>\n      <th>D20250131</th>\n      <th>D20250228</th>\n      <th>D20250331</th>\n      <th>D20250430</th>\n      <th>D20250531</th>\n      <th>D20250630</th>\n      <th>D20250731</th>\n    </tr>\n    <tr>\n      <th>PointKey</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n   ...

# %%
cumdisp_df.dtypes
# Out:
# X_TWD97      float64
# Y_TWD97      float64
# D20160430    float64
# D20160531    float64
# D20160630    float64
#               ...
# D20250331    float64
# D20250430    float64
# D20250531    float64
# D20250630    float64
# D20250731    float64
# Length: 114, dtype: object

# %% [markdown]
# #### check index alignment

# %%
delta_slope_df.index.equals(cumdisp_df.index)
# Out:
# True

# %% [markdown]
# #### calculate the table of values for correction

# %%
measure_cols = [col for col in cumdisp_df.columns if col.startswith("D")]
cumdisp_measure_df = cumdisp_df.loc[:, measure_cols]
cumdisp_measure_df
# Out:
#                        D20160430  D20160531  D20160630  D20160731  D20160831  \
# PointKey
# X161701940Y2594931653      13.74      13.79       6.58      -5.08     -13.78
# X161738005Y2601967325      -5.32       0.27       2.06      -0.08      -3.70
# X222663584Y2633791963    -186.42    -187.15    -188.07    -188.80    -189.23
# X222701522Y2633710990    -133.49    -135.75    -137.24    -137.73    -137.27
#
#                        D20250731
# PointKey
# X161701940Y2594931653      46.16
# X161738005Y2601967325     106.84
# X161772290Y2613200957    -151.58
# X161811991Y2613199872    -152.35
# X161821971Y2594928398      89.80
# ...                          ...
# X222623939Y2633793094    -176.12
# X222626422Y2633872934    -187.29
# X222661878Y2633712121    -155.41
# X222663584Y2633791963    -189.93
# X222701522Y2633710990    -136.23
#
# [1095487 rows x 112 columns]

# %%
delta_slope_df.index.equals(cumdisp_measure_df.index)
# Out:
# True

# %%
cumdisp_df.index.equals(cumdisp_measure_df.index)
# Out:
# True

# %% [markdown]
# #### we also need a table of values for correction with same shape, `907462 rows × 112 columns`
#
# `N` rows of $\Delta_{slope}$ x `M` columns of numeric datetime
#
# ```
# arr1 = np.arange(1, 6)
# arr2 = np.arange(11, 5, -1)
# arr1, arr2
# >> (array([1, 2, 3, 4, 5]), array([11, 10,  9,  8,  7,  6]))
# ```
#
# ```
# np.multiply(arr1.reshape(-1, 1), arr2)
# >> array([[11, 10,  9,  8,  7,  6],
#        [22, 20, 18, 16, 14, 12],
#        [33, 30, 27, 24, 21, 18],
#        [44, 40, 36, 32, 28, 24],
#        [55, 50, 45, 40, 35, 30]])
# ```
#
# ```
# np.outer(arr1, arr2)
# >> array([[11, 10,  9,  8,  7,  6],
#        [22, 20, 18, 16, 14, 12],
#        [33, 30, 27, 24, 21, 18],
#        [44, 40, 36, 32, 28, 24],
#        [55, 50, 45, 40, 35, 30]])
# ```

# %%
measure_cols_numeric = [
    pd.to_datetime(col[1:]) + relativedelta(days=1) for col in measure_cols
]
measure_cols_numeric = np.array(
    [(ele - measure_cols_numeric[0]).days for ele in measure_cols_numeric]
)

measure_cols_numeric[:5]
# Out:
# array([  0,  31,  61,  92, 123])

# %%
slope_array = delta_slope_df["Predicted"].values
correction_value_arr = np.outer(slope_array, measure_cols_numeric)
correction_value_df = pd.DataFrame(
    data=correction_value_arr,
    index=cumdisp_measure_df.index,
    columns=cumdisp_measure_df.columns,
)
show(correction_value_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_14453b6d_6da4_4a34_858b_b024cc42440c"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.5 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_14453b6d_6da4_4a34_858b_b024cc42440c:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 1,095,487x112 to 90x90 as maxBytes=64KB", "filtered_row_count": 1095397, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th
20171231</th>\n      <th>D20180131</th>\n      <th>D20180228</th>\n      <th>D20180331</th>\n      <th>D20180430</th>\n      <th>D20180531</th>\n      <th>D20180630</th>\n      <th>D20180731</th>\n      <th>D20180831</th>\n      <th>D20180930</th>\n      <th>D20181031</th>\n      <th>D20181130</th>\n      <th>D20181231</th>\n      <th>D20190131</th>\n      <th>D20190228</th>\n      <th>D20190331</th>\n      <th>D20190430</th>\n      <th>D20190531</th>\n      <th>D20190630</th>\n      <th>D20190731</th>\n      <th>D20190831</th>\n      <th>D20190930</th>\n      <th>D20191031</th>\n      <th>D20191130</th>\n      <th>D20191231</th>\n      <th>D20211130</th>\n      <th>D20211231</th>\n      <th>D20220131</th>\n      <th>D20220228</th>\n      <th>D20220331</th>\n      <th>D20220430</th>\n      <th>D20220531</th>\n      <th>D20220630</th>\n      <th>D20220731</th>\n      <th>D20220831</th>\n      <th>D20220930</th>\n      <th>D20221031</th>\n      <th>D20221130</th>\n      <th>D20221231</th>\n      <th>D20230131</th>\n      <th>D20230228</th>\n      <th>D20230331</th>\n      <th>D20230430</th>\n      <th>D20230531</th>\n      <th>D20230630</th>\n      <th>D20230731</th>\n      <th>D20230831</th>\n      <th>D20230930</th>\n      <th>D20231031</th>\n      <th>D20231130</th>\n      <th>D20231231</th>\n      <th>D20240131</th>\n      <th>D20240229</th>\n      <th>D20240331</th>\n      <th>D20240430</th>\n      <th>D20240531</th>\n      <th>D20240630</th>\n      <th>D20240731</th>\n      <th>D20240831</th>\n      <th>D20240930</th>\n      <th>D20241031</th>\n      <th>D20241130</th>\n      <th>D20241231</th>\n      <th>D20250131</th>\n      <th>D20250228</th>\n      <th>D20250331</th>\n      <th>D20250430</th>\n      <th>D20250531</th>\n      <th>D20250630</th>\n      <th>D20250731</th>\n    </tr>\n    <tr>\n      <th>PointKey</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th> ...

# %%
corrected_cumdisp_df.shape[0] == cumdisp_df.shape[0]
# Out:
# True

# %%
corrected_cumdisp_df.dtypes
# Out:
# D20160430    float64
# D20160531    float64
# D20160630    float64
# D20160731    float64
# D20160831    float64
#               ...
# D20250331    float64
# D20250430    float64
# D20250531    float64
# D20250630    float64
# D20250731    float64
# Length: 112, dtype: object

# %%
info_df = cumdisp_df.loc[:, ~cumdisp_df.columns.isin(measure_cols)]
final_output_pdf = pd.concat([info_df, corrected_cumdisp_df], axis=1)

# %%
# Calculate memory usage in bytes
mem_bytes = cumdisp_df.memory_usage(deep=True).sum()
# Convert to megabytes
mem_megabytes = mem_bytes / (1024**2)

print(f"Memory usage: {mem_megabytes:.3f} MB")
# Out:
# Memory usage: 1034.290 MB

# %%
final_output_pdf.to_pickle(
    r"CORRECTED_Monthly_CUMDISP_saveqgis_Oct2025_updateNov.xz"
)

# %%
cumdisp_measure_df.iloc[0, :].plot()
corrected_cumdisp_df.iloc[0, :].plot()
# Out:
# <Axes: >
