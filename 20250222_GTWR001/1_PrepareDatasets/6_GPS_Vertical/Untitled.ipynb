# %%
from appgeopy import *
from my_packages import *

# Set matplotlib for inline plotting
# %matplotlib inline
plt.style.use("default")  # Optional: clean plot style

# %%
sys.path.append(
    r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\3_MGTWR\20250415_PCA_Imputation"
)
from pca_imputation import *

# %%
select_GPS_fpath = r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\1_PrepareDatasets\6_GPS_Vertical\GPS_station_and_filepath.pkl"
with open(select_GPS_fpath, "rb") as f:
    gps_and_fpath_dict = pickle.load(f)

gps_and_fpath_dict
# Out:
# {'ALIS': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\ALIS.csv',
#  'BDES': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\BDES.csv',
#  'C001': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\C001.csv',
#  'C002': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\C002.csv',
#  'CAOT': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\CAOT.csv',
#  'CHIA': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\CHIA.csv',
#  'CHIN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\CHIN.csv',
#  'CHIU': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\CHIU.csv',
#  'CHUA': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\CHUA.csv',
#  'CHUK': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\CHUK.csv',
#  'CHYI': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\CHYI.csv',
#  'CWEN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\CWEN.csv',
#  'DNAN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\DNAN.csv',
#  'DOSH': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\DOSH.csv',
#  'DPIN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\DPIN.csv',
#  'ERLN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\ERLN.csv',
#  'FCU1': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\FCU1.csv',
#  'FKDO': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\FKDO.csv',
#  'FNGU': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\FNGU.csv',
#  'FUNY': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\FUNY.csv',
#  'FUQE': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\FUQE.csv',
#  'GFES': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GFES.csv',
#  'GS05': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS05.csv',
#  'GS06': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS06.csv',
#  'GS07': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS07.csv',
#  'GS17': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS17.csv',
#  'GS18': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS18.csv',
#  'GS21': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS21.csv',
#  'GS22': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS22.csv',
#  'GS23': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS23.csv',
#  'GS24': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS24.csv',
#  'GS25': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS25.csv',
#  'GS26': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS26.csv',
#  'GS27': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS27.csv',
#  'GS38': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS38.csv',
#  'GS39': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS39.csv',
#  'GS41': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS41.csv',
#  'GS63': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS63.csv',
#  'GS64': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS64.csv',
#  'GS66': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS66.csv',
#  'GS67': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS67.csv',
#  'GS68': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GS68.csv',
#  'GUK2': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GUK2.csv',
#  'GUKN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\GUKN.csv',
#  'HLIU': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\HLIU.csv',
#  'HNES': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\HNES.csv',
#  'HOPN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\HOPN.csv',
#  'HSUE': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\HSUE.csv',
#  'HUWE': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\HUWE.csv',
#  'HUYS': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\HUYS.csv',
#  'ICHU': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\ICHU.csv',
#  'JHCI': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\JHCI.csv',
#  'JONP': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\JONP.csv',
#  'KLN2': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\KLN2.csv',
#  'KTES': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\KTES.csv',
#  'KZN1': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\KZN1.csv',
#  'LAIG': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\LAIG.csv',
#  'LNJS': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\LNJS.csv',
#  'LOYE': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\LOYE.csv',
#  'LSB0': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\LSB0.csv',
#  'LUKN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\LUKN.csv',
#  'NSHE': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\NSHE.csv',
#  'PAKU': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\PAKU.csv',
#  'PEI1': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\PEI1.csv',
#  'PINT': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\PINT.csv',
#  'PKGM': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\PKGM.csv',
#  'PLIM': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\PLIM.csv',
#  'RENI': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\RENI.csv',
#  'S016': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\S016.csv',
#  'S103': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\S103.csv',
#  'S167': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\S167.csv',
#  'SANL': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\SANL.csv',
#  'SGUN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\SGUN.csv',
#  'SINY': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\SINY.csv',
#  'SJPU': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\SJPU.csv',
#  'SSUN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\SSUN.csv',
#  'SUN1': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\SUN1.csv',
#  'TATA': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\TATA.csv',
#  'TKJS': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\TKJS.csv',
#  'TSLN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\TSLN.csv',
#  'TUNS': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\TUNS.csv',
#  'VR01': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\VR01.csv',
#  'VR02': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\VR02.csv',
#  'VR03': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\VR03.csv',
#  'W021': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\W021.csv',
#  'W029': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\W029.csv',
#  'WANS': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\WANS.csv',
#  'WFEN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\WFEN.csv',
#  'YSLL': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\YSLL.csv',
#  'YUNL': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\YUNL.csv',
#  'YUSN': 'E:\\SUBSIDENCE_PROJECT_DATA\\GPS_2024_HsuYaru\\2__Processed\\A__Fulltime\\YUSN.csv',
#  'CHSG': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\CHSG.csv',
#  'DAHU': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\DAHU.csv',
#  'FRES': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\FRES.csv',
#  'GLES': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\GLES.csv',
#  'GS36': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\GS36.csv',
#  'GS82': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\GS82.csv',
#  'GS83': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\GS83.csv',
#  'GS84': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\GS84.csv',
#  'HLES': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\HLES.csv',
#  'JHSN': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\JHSN.csv',
#  'JSAN': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\JSAN.csv',
#  'JUCI': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\JUCI.csv',
#  'MDES': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\MDES.csv',
#  'NTUH': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\NTUH.csv',
#  'PUS2': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\PUS2.csv',
#  'SJES': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\SJES.csv',
#  'SLES': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\SLES.csv',
#  'SSES': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\SSES.csv',
#  'SUAN': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\SUAN.csv',
#  'TAPN': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\TAPN.csv',
#  'YOKN': 'E:\\GPSData+4Calibration+PSInSAR\\AVAILABLE_4CALIBRATION\\GPS_nearby\\YOKN.csv'}

# %%
insar_df = pd.read_pickle(
    r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\1_PrepareDatasets\3_InSAR\ASC_overlap_desc_+pointkey_TWD97.pkl",
    compression="zip",
)
insar_df.columns[:10]
# Out:
# Index(['CODE', 'PointKey', 'HEIGHT', 'H_STDEV', 'VEL', 'V_STDEV', 'COHERENCE',
#        'EFF_AREA', 'D20160414', 'D20160508'],
#       dtype='object')

# %% [raw]
# savefolder = "PCA_imputed_GPS"
#
# if not os.path.exists(savefolder):
#     os.makedirs(savefolder)
#
# all_stations = list(gps_and_fpath_dict.keys())
#
# for select_station in tqdm(all_stations[:1]):
#     # select_station = "TKJS"
#
#     fpath_byStation = gps_and_fpath_dict[select_station]
#
#     GPS_df_byStation = pd.read_csv(
#         fpath_byStation, parse_dates=[0], index_col=[0]
#     )
#
#     colnames = GPS_df_byStation.columns
#     subset_byStation = GPS_df_byStation.loc["2016-4-14":"2022-1"]
#     # subset_byStation = subset_byStation.subtract(subset_byStation.iloc[0, :]) * 1000
#
#     new_colnames = [col.replace("m", "mm") for col in colnames]
#     subset_byStation.columns = new_colnames
#
#     for col in subset_byStation.columns:
#         gps_series = subset_byStation.loc[:, col]
#         series_name = gps_series.name
#         series_newname = series_name.replace("(", "_pca(")
#         results = run_fundamental_signal_extraction(
#             data=gps_series,
#             signal_strength="strong",  # Try 'light', 'moderate', or 'strong'
#         )
#
#         fundamental_signal = pd.Series(
#             results["signal_results"]["fundamental_signal"],
#             index=results["signal_results"]["time_values"],
#         )
#
#         subset_byStation[series_newname] = subset_byStation.index.map(
#             fundamental_signal
#         )
#
#     subset_byStation = (
#         subset_byStation.subtract(subset_byStation.iloc[0, :]) * 1000
#     )
#     subset_byStation.to_csv(
#         os.path.join(savefolder, f"{select_station}_pca.csv"), index=True
#     )
#     fig, axes = plt.subplots(3, 1, figsize=(12, 4), sharex=True)
#     for col_idx in [0, 1, 2]:
#         ax = axes[col_idx]
#         ax.plot(subset_byStation.iloc[:, [col_idx]], label=series_name)
#         ax.plot(subset_byStation.iloc[:, [col_idx + 3]], label=series_newname)
#
#     fig.suptitle(select_station)
#     visualize.save_figure(
#         fig=fig, savepath=os.path.join(savefolder, f"{select_station}_fig.png")
#     )
#     plt.close()

# %%
# ================================================================
# GPS DATA PROCESSING WITH PCA SIGNAL EXTRACTION
# ================================================================

# ----------------------------------------------------------------
# SETUP: Create output directory
# ----------------------------------------------------------------
savefolder = "PCA_imputed_GPS"

if not os.path.exists(savefolder):
    os.makedirs(savefolder)
    print(f"Created output directory: {savefolder}")

# ----------------------------------------------------------------
# MAIN PROCESSING LOOP: Process each GPS station
# ----------------------------------------------------------------
all_stations = list(gps_and_fpath_dict.keys())

for select_station in tqdm(all_stations[:], desc="Processing GPS stations"):
    try:
        # print(f"\nProcessing station: {select_station}")

        # ----------------------------------------------------------------
        # DATA LOADING: Load GPS data for current station
        # ----------------------------------------------------------------
        fpath_byStation = gps_and_fpath_dict[select_station]

        GPS_df_byStation = pd.read_csv(
            fpath_byStation, parse_dates=[0], index_col=[0]
        )

        # ----------------------------------------------------------------
        # DATA PREPROCESSING: Time subset and column naming
        # ----------------------------------------------------------------
        # Extract time subset (2016-4-14 to 2022-1)
        subset_byStation = GPS_df_byStation.loc["2016-4-14":"2022-1"]

        # Update column names: replace 'm' with 'mm' for clarity
        colnames = GPS_df_byStation.columns
        new_colnames = [col.replace("m", "mm") for col in colnames]
        subset_byStation.columns = new_colnames

        # print(f"  Data shape: {subset_byStation.shape}")
        # print(f"  Columns: {list(subset_byStation.columns)}")

        # ----------------------------------------------------------------
        # PCA SIGNAL EXTRACTION: Apply to each coordinate column
        # ----------------------------------------------------------------
        for col in subset_byStation.columns:
            # print(f"  Processing column: {col}")

            # Extract time series for current coordinate
            gps_series = subset_byStation.loc[:, col]
            series_name = gps_series.name

            # Create new column name for PCA results
            series_newname = series_name.replace("(", "_pca(")

            # Apply PCA signal extraction
            results = run_fundamental_signal_extraction(
                data=gps_series,
                signal_strength="strong",  # Extract only major trends/patterns
            )

            # Extract fundamental signal as pandas Series
            fundamental_signal = pd.Series(
                results["signal_results"]["fundamental_signal"],
                index=results["signal_results"]["time_values"],
            )

            # Add PCA results to dataframe
            subset_byStation[series_newname] = subset_byStation.index.map(
                fundamental_signal
            )

        # ----------------------------------------------------------------
        # DATA NORMALIZATION: Remove initial offset and convert to mm
        # ----------------------------------------------------------------
        # Subtract first row values (remove initial position) and convert to mm
        subset_byStation = (
            subset_byStation.subtract(subset_byStation.iloc[0, :]) * 1000
        )

        # ----------------------------------------------------------------
        # SAVE RESULTS: Export processed data
        # ----------------------------------------------------------------
        output_filepath = os.path.join(savefolder, f"{select_station}_pca.csv")
        subset_byStation.to_csv(output_filepath, index=True)
        # print(f"  Saved processed data: {output_filepath}")

        # ----------------------------------------------------------------
        # VISUALIZATION: Create comparison plots
        # ----------------------------------------------------------------
        fig, axes = plt.subplots(3, 1, figsize=(12, 4), sharex=True)

        # Plot original vs PCA-processed data for each coordinate (X, Y, Z)
        for col_idx in [0, 1, 2]:
            ax = axes[col_idx]

            # Original data (columns 0, 1, 2)
            original_col = subset_byStation.iloc[:, col_idx]
            ax.plot(
                original_col, label=f"Original {original_col.name}", alpha=0.7
            )

            # PCA-processed data (columns 3, 4, 5)
            pca_col = subset_byStation.iloc[:, col_idx + 3]
            ax.plot(pca_col, label=f"PCA {pca_col.name}", linewidth=2)

            ax.legend()
            ax.grid(True, alpha=0.3)
            ax.set_ylabel("Displacement (mm)")

        # Set plot title and labels
        fig.suptitle(f"GPS Station: {select_station} - Original vs PCA Signals")
        axes[-1].set_xlabel("Time")

        # ----------------------------------------------------------------
        # SAVE PLOTS: Export visualization
        # ----------------------------------------------------------------
        plot_filepath = os.path.join(savefolder, f"{select_station}_fig.png")
        visualize.save_figure(fig=fig, savepath=plot_filepath)
        plt.close()

        print(f"  Saved plot: {plot_filepath}")
    except Exception as e:
        print(e)
        pass

print(f"\n{'='*50}")
print("GPS processing complete!")
print(f"Results saved in: {savefolder}")
print(f"{'='*50}")
# Out:
# Processing GPS stations:   0%|          | 0/112 [00:00<?, ?it/s]
#   Saved plot: PCA_imputed_GPS\ALIS_fig.png
#   Saved plot: PCA_imputed_GPS\BDES_fig.png
#   Saved plot: PCA_imputed_GPS\C001_fig.png
#   Saved plot: PCA_imputed_GPS\C002_fig.png
#   Saved plot: PCA_imputed_GPS\CAOT_fig.png
#   Saved plot: PCA_imputed_GPS\CHIA_fig.png
#   Saved plot: PCA_imputed_GPS\CHIN_fig.png
#   Saved plot: PCA_imputed_GPS\CHIU_fig.png
#   Saved plot: PCA_imputed_GPS\CHUA_fig.png
#   Saved plot: PCA_imputed_GPS\CHUK_fig.png
#   Saved plot: PCA_imputed_GPS\CHYI_fig.png
#   Saved plot: PCA_imputed_GPS\CWEN_fig.png
#   Saved plot: PCA_imputed_GPS\DNAN_fig.png
#   Saved plot: PCA_imputed_GPS\DOSH_fig.png
#   Saved plot: PCA_imputed_GPS\DPIN_fig.png
#   Saved plot: PCA_imputed_GPS\ERLN_fig.png
# Parameter search failed: No valid parameter combinations found, using conservative defaults
# Warning: Embedding dimension (8) is too large for the data length (0).
# Adjusting embedding dimension to 1.
# Warning: Further adjusting embedding dimension to 2 to ensure at least one vector.
# negative dimensions are not allowed
#   Saved plot: PCA_imputed_GPS\FKDO_fig.png
#   Saved plot: PCA_imputed_GPS\FNGU_fig.png
#   Saved plot: PCA_imputed_GPS\FUNY_fig.png
#   Saved plot: PCA_imputed_GPS\FUQE_fig.png
#   Saved plot: PCA_imputed_GPS\GFES_fig.png
#   Saved plot: PCA_imputed_GPS\GS05_fig.png
#   Saved plot: PCA_imputed_GPS\GS06_fig.png
#   Saved plot: PCA_imputed_GPS\GS07_fig.png
#   Saved plot: PCA_imputed_GPS\GS17_fig.png
#   Saved plot: PCA_imputed_GPS\GS18_fig.png
#   Saved plot: PCA_imputed_GPS\GS21_fig.png
#   Saved plot: PCA_imputed_GPS\GS22_fig.png
#   Saved plot: PCA_imputed_GPS\GS23_fig.png
#   Saved plot: PCA_imputed_GPS\GS24_fig.png
#   Saved plot: PCA_imputed_GPS\GS25_fig.png
#   Saved plot: PCA_imputed_GPS\GS26_fig.png
#   Saved plot: PCA_imputed_GPS\GS27_fig.png
#   Saved plot: PCA_imputed_GPS\GS38_fig.png
#   Saved plot: PCA_imputed_GPS\GS39_fig.png
#   Saved plot: PCA_imputed_GPS\GS41_fig.png
#   Saved plot: PCA_imputed_GPS\GS63_fig.png
#   Saved plot: PCA_imputed_GPS\GS64_fig.png
#   Saved plot: PCA_imputed_GPS\GS66_fig.png
#   Saved plot: PCA_imputed_GPS\GS67_fig.png
#   Saved plot: PCA_imputed_GPS\GS68_fig.png
#   Saved plot: PCA_imputed_GPS\GUK2_fig.png
#   Saved plot: PCA_imputed_GPS\GUKN_fig.png
#   Saved plot: PCA_imputed_GPS\HLIU_fig.png
#   Saved plot: PCA_imputed_GPS\HNES_fig.png
#   Saved plot: PCA_imputed_GPS\HOPN_fig.png
#   Saved plot: PCA_imputed_GPS\HSUE_fig.png
#   Saved plot: PCA_imputed_GPS\HUWE_fig.png
#   Saved plot: PCA_imputed_GPS\HUYS_fig.png
#   Saved plot: PCA_imputed_GPS\ICHU_fig.png
#   Saved plot: PCA_imputed_GPS\JHCI_fig.png
#   Saved plot: PCA_imputed_GPS\JONP_fig.png
#   Saved plot: PCA_imputed_GPS\KLN2_fig.png
#   Saved plot: PCA_imputed_GPS\KTES_fig.png
#   Saved plot: PCA_imputed_GPS\KZN1_fig.png
#   Saved plot: PCA_imputed_GPS\LAIG_fig.png
#   Saved plot: PCA_imputed_GPS\LNJS_fig.png
#   Saved plot: PCA_imputed_GPS\LOYE_fig.png
#   Saved plot: PCA_imputed_GPS\LSB0_fig.png
#   Saved plot: PCA_imputed_GPS\LUKN_fig.png
#   Saved plot: PCA_imputed_GPS\NSHE_fig.png
#   Saved plot: PCA_imputed_GPS\PAKU_fig.png
#   Saved plot: PCA_imputed_GPS\PEI1_fig.png
#   Saved plot: PCA_imputed_GPS\PINT_fig.png
#   Saved plot: PCA_imputed_GPS\PKGM_fig.png
#   Saved plot: PCA_imputed_GPS\PLIM_fig.png
#   Saved plot: PCA_imputed_GPS\RENI_fig.png
#   Saved plot: PCA_imputed_GPS\S016_fig.png
#   Saved plot: PCA_imputed_GPS\S103_fig.png
#   Saved plot: PCA_imputed_GPS\S167_fig.png
#   Saved plot: PCA_imputed_GPS\SANL_fig.png
#   Saved plot: PCA_imputed_GPS\SGUN_fig.png
#   Saved plot: PCA_imputed_GPS\SINY_fig.png
#   Saved plot: PCA_imputed_GPS\SJPU_fig.png
#   Saved plot: PCA_imputed_GPS\SSUN_fig.png
#   Saved plot: PCA_imputed_GPS\SUN1_fig.png
#   Saved plot: PCA_imputed_GPS\TATA_fig.png
#   Saved plot: PCA_imputed_GPS\TKJS_fig.png
#   Saved plot: PCA_imputed_GPS\TSLN_fig.png
#   Saved plot: PCA_imputed_GPS\TUNS_fig.png
#   Saved plot: PCA_imputed_GPS\VR01_fig.png
#   Saved plot: PCA_imputed_GPS\VR02_fig.png
#   Saved plot: PCA_imputed_GPS\VR03_fig.png
#   Saved plot: PCA_imputed_GPS\W021_fig.png
#   Saved plot: PCA_imputed_GPS\W029_fig.png
#   Saved plot: PCA_imputed_GPS\WANS_fig.png
#   Saved plot: PCA_imputed_GPS\WFEN_fig.png
#   Saved plot: PCA_imputed_GPS\YSLL_fig.png
#   Saved plot: PCA_imputed_GPS\YUNL_fig.png
#   Saved plot: PCA_imputed_GPS\YUSN_fig.png
#   Saved plot: PCA_imputed_GPS\CHSG_fig.png
#   Saved plot: PCA_imputed_GPS\DAHU_fig.png
#   Saved plot: PCA_imputed_GPS\FRES_fig.png
#   Saved plot: PCA_imputed_GPS\GLES_fig.png
#   Saved plot: PCA_imputed_GPS\GS36_fig.png
#   Saved plot: PCA_imputed_GPS\GS82_fig.png
#   Saved plot: PCA_imputed_GPS\GS83_fig.png
#   Saved plot: PCA_imputed_GPS\GS84_fig.png
#   Saved plot: PCA_imputed_GPS\HLES_fig.png
#   Saved plot: PCA_imputed_GPS\JHSN_fig.png
#   Saved plot: PCA_imputed_GPS\JSAN_fig.png
#   Saved plot: PCA_imputed_GPS\JUCI_fig.png
#   Saved plot: PCA_imputed_GPS\MDES_fig.png
#   Saved plot: PCA_imputed_GPS\NTUH_fig.png
#   Saved plot: PCA_imputed_GPS\PUS2_fig.png
#   Saved plot: PCA_imputed_GPS\SJES_fig.png
#   Saved plot: PCA_imputed_GPS\SLES_fig.png
#   Saved plot: PCA_imputed_GPS\SSES_fig.png
#   Saved plot: PCA_imputed_GPS\SUAN_fig.png
#   Saved plot: PCA_imputed_GPS\TAPN_fig.png
#   Saved plot: PCA_imputed_GPS\YOKN_fig.png
#
# ==================================================
# GPS processing complete!
# Results saved in: PCA_imputed_GPS
# ==================================================
