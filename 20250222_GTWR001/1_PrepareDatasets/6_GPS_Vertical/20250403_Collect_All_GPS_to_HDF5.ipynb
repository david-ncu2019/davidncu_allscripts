# %%
from my_packages import *
from appgeopy import *

# %%
gps_shp_fpath001 = r"E:\006_InSAR_Project_2022\GPSDataWorkspace\Selected_ActiveGPS_4Calibration_20220609.shp"
gps_shp001 = gpd.read_file(gps_shp_fpath001)

gps_shp_fpath002 = r"E:\SUBSIDENCE_PROJECT_DATA\GPS_2024_HsuYaru\Geodatabase\gps2024_hsuyaru_twd97.shp"
gps_shp002 = gpd.read_file(gps_shp_fpath002)

# %%
gps_shp001.crs==gps_shp002.crs
# Out:
# True

# %%
all_gps_stations = sorted(set(pd.concat([gps_shp001["STATION"], gps_shp002["STATION"]], axis=0, ignore_index=True)))
# Out:
# ['8118',
#  'ALIS',
#  'BDES',
#  'BKBL',
#  'C001',
#  'C002',
#  'CAOT',
#  'CHIA',
#  'CHIN',
#  'CHIU',
#  'CHSG',
#  'CHUA',
#  'CHUK',
#  'CHYI',
#  'CHYN',
#  'CWEN',
#  'DAHU',
#  'DANI',
#  'DNAN',
#  'DOSH',
#  'DPIN',
#  'ERLN',
#  'FCU1',
#  'FKD2',
#  'FKDO',
#  'FNGU',
#  'FRES',
#  'FUNY',
#  'FUQE',
#  'GANK',
#  'GFES',
#  'GLES',
#  'GS04',
#  'GS05',
#  'GS06',
#  'GS07',
#  'GS17',
#  'GS18',
#  'GS21',
#  'GS22',
#  'GS23',
#  'GS24',
#  'GS25',
#  'GS26',
#  'GS27',
#  'GS29',
#  'GS36',
#  'GS38',
#  'GS39',
#  'GS40',
#  'GS41',
#  'GS42',
#  'GS43',
#  'GS44',
#  'GS63',
#  'GS64',
#  'GS66',
#  'GS67',
#  'GS68',
#  'GS82',
#  'GS83',
#  'GS84',
#  'GS88',
#  'GS91',
#  'GS92',
#  'GUK2',
#  'GUKN',
#  'GUKW',
#  'HLES',
#  'HLIU',
#  'HNES',
#  'HOKN',
#  'HOPN',
#  'HSUE',
#  'HUWE',
#  'HUYS',
#  'ICHU',
#  'JHCI',
#  'JHSN',
#  'JONP',
#  'JSAN',
#  'JUCI',
#  'JUNA',
#  'JWEN',
#  'KAWN',
#  'KLN2',
#  'KTES',
#  'KULN',
#  'KZN1',
#  'LAIG',
# ...

# %%
gps_shp002.columns
# Out:
# Index(['STATION', 'LONG', 'LAT', 'X_TWD97', 'Y_TWD97', 'geometry'], dtype='object')
