# %%
from appgeopy import *
from my_packages import *

# %% [markdown]
# # PART 1: CONVERT ORIGINAL DATA TO MONTHLY DATA

# %% [raw]
# h5_fpath = "20250313_MLCW_CRFP_v11.h5"
# # initiate MLCW class object
# mlcw_obj = MLCW(h5_fpath=h5_fpath)
# mlcw_data, mlcw_metadata = mlcw_obj.get_data()
# available_stations = mlcw_obj.list_stations()
# available_stations[:5]

# %% [raw]
# mlcw_obj.list_structure(mlcw_data)

# %% [raw]
# # select_station = available_stations[0]
# for select_station in tqdm(available_stations):
#
#     value_types = ["ref2base", "ringbyring", "compactbylayer"]
#
#     mlcw_data[select_station]["monthly_values"] = {}
#
#     for value_type in value_types:
#         df_byValueType = mlcw_obj.build_dataframe(station=select_station, value_type=value_type)
#         monthly_df_byValueType = df_byValueType.resample("MS", axis=1).mean()
#         mlcw_data[select_station]["monthly_values"][value_type] = monthly_df_byValueType.to_numpy()
#
#     mlcw_data[select_station]["monthly_date"] = np.array(monthly_df_byValueType.columns.strftime("%Y%m%d"))

# %% [raw]
# # - - - - - - - - - - - - - - - - -
# # Add new description and metadata
# # - - - - - - - - - - - - - - - - -
#
# mlcw_metadata["Description_4"] = "2025/03/14: Resampling the data table for the entire time span. Later I will take the data table starting from 2014 to 2021"
# today_string = datetime.now().strftime("%Y%m%d")
#
# # Write updated data and metadata back to the HDF5 file
# with h5py.File(f"{today_string}_MLCW_CRFP_v12.h5", "w") as hdf5_file:
#     gwatertools.h5pytools.data_to_hdf5(hdf5_file, mlcw_data)
#     gwatertools.h5pytools.metadata_to_hdf5(hdf5_file, mlcw_metadata)

# %% [markdown]
# # PART 2: EXTRACT DATA FROM 2014 TO 2021 FOR FURTHER PROCESSING

# %%
h5_fpath = "20250314_MLCW_CRFP_v12.h5"
# initiate MLCW class object
mlcw_obj = MLCW(h5_fpath=h5_fpath)
mlcw_data, mlcw_metadata = mlcw_obj.get_data()
available_stations = mlcw_obj.list_stations()
available_stations[:5]
# Out:
# ['ANHE', 'ANNAN', 'BEICHEN', 'CANLIN', 'DONGGUANG']

# %%
station2process = []

# select_station = available_stations[0]
for select_station in tqdm(available_stations):

    df = mlcw_obj.build_dataframe(station=select_station, value_type="original")

    df_year_list = df.columns.strftime("%Y").unique().tolist()

    expected_years = np.arange(2014, 2022).astype(str).tolist()

    check_flag = set(expected_years).issubset(df_year_list)

    if check_flag:
        station2process.append(select_station)
# Out:
#   0%|          | 0/38 [00:00<?, ?it/s]

# %%
mlcw_obj.list_structure(mlcw_data)
# Out:
# ├── ANHE
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── ANNAN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── BEICHEN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── CANLIN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── DONGGUANG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── ERLUN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── FENGAN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── FENGRONG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── GUANGFU
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── HAIFENG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── HONGLUN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── HUNAN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── HUWEI
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── JIANYANG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── JIAXING
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── JINHU_XIN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── JIUZHUANG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── KECUO
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── LONGYAN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── LUNFENG_XIN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── NANGUANG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── NEILIAO
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── QIAOYI
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── TANQIFENXIAO
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── TUKU
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── XIGANG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── XINGHUA
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── XINJIE
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── XINPI
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── XINSHENG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── XINXING
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── XIUTAN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── XIZHOU
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── YIWU
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── YUANCHANG
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── ZHENGMIN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# ├── ZHENNAN
# │   ├── classify
# │   │   ├── depth
# │   │   └── layer
# │   ├── date
# │   ├── depth
# │   ├── monthly_date
# │   ├── monthly_values
# │   │   ├── compactbylayer
# │   │   ├── ref2base
# │   │   └── ringbyring
# │   └── values
# │       ├── compactbylayer
# │       ├── original
# │       ├── ref2base
# │       └── ringbyring
# └── ZHUTANG
#     ├── classify
#     │   ├── depth
#     │   └── layer
#     ├── date
#     ├── depth
#     ├── monthly_date
#     ├── monthly_values
#     │   ├── compactbylayer
#     │   ├── ref2base
#     │   └── ringbyring
#     └── values
#         ├── compactbylayer
#         ├── original
#         ├── ref2base
#         └── ringbyring

# %%
cache = []

# select_station = station2process[0]
for select_station in tqdm(station2process):

    temp = [
        {select_station: {segment: mlcw_data[select_station][segment]}}
        for segment in ["depth", "classify", "monthly_date", "monthly_values"]
    ]
    cache.extend(temp)

new_mlcw_data = merge_dicts(*cache)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]

# %%
cache = []

exclude_station = [stat for stat in available_stations if stat not in station2process]

for key in mlcw_metadata.keys():
    if key not in exclude_station:
        cache.append({key:mlcw_metadata[key]})

new_mlcw_metadata = merge_dicts(*cache)

# %%
# - - - - - - - - - - - - - - - - -
# Add new description and metadata
# - - - - - - - - - - - - - - - - -
today_string = datetime.now().strftime("%Y%m%d")

# Write updated data and metadata back to the HDF5 file
with h5py.File(f"{today_string}_MLCW_CRFP_monthly_v1.h5", "w") as hdf5_file:
    gwatertools.h5pytools.data_to_hdf5(hdf5_file, new_mlcw_data)
    gwatertools.h5pytools.metadata_to_hdf5(hdf5_file, new_mlcw_metadata)
