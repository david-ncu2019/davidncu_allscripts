# %%
from appgeopy import *
from my_packages import *
from tools import *

# %%
h5_fpath = "20250309_MLCW_CRFP_v8.h5"
# initiate MLCW class object
mlcw_obj = MLCW(h5_fpath=h5_fpath)
mlcw_data, mlcw_metadata = mlcw_obj.get_data()
available_stations = mlcw_obj.list_stations()
available_stations[:5]
# Out:
# ['ANHE', 'ANNAN', 'BEICHEN', 'CANLIN', 'DONGGUANG']

# %%
mlcw_obj.list_structure(mlcw_data)
# Out:
# ├── ANHE
# │   ├── date
# │   ├── depth
# │   └── values
# │       ├── col_diff
# │       ├── model_original
# │       ├── original
# │       └── ref2base
# ├── ANNAN
# │   ├── date
# │   ├── depth
# │   └── values
# │       ├── col_diff
# │       ├── model_original
# │       ├── original
# │       └── ref2base
# ├── BEICHEN
# │   ├── date
# │   ├── depth
# │   └── values
# │       ├── col_diff
# │       ├── model_original
# │       ├── original
# │       └── ref2base
# ├── CANLIN
# │   ├── date
# │   ├── depth
# │   └── values
# │       ├── col_diff
# │       ├── model_original
# │       ├── original
# │       └── ref2base
# ├── DONGGUANG
# │   ├── date
# │   ├── depth
# │   └── values
# │       ├── col_diff
# │       ├── model_original
# │       ├── original
# │       └── ref2base
# ├── ERLUN
# │   ├── date
# │   ├── depth
# │   └── values
# │       ├── col_diff
# │       ├── model_original
# │       ├── original
# │       └── ref2base
# ├── FENGAN
# │   ├── date
# │   ├── depth
# ...

# %%
# select_station = available_stations[2]
for select_station in tqdm(available_stations):
    try:
    
        model_original_df = mlcw_obj.build_dataframe(station=select_station, value_type="model_original", end_date="2022")
        
        row_differencing = model_original_df.diff(1)
        row_differencing.iloc[0, :] = model_original_df.iloc[0, :]
        
        row_diff_ref2first = row_differencing.subtract(row_differencing.iloc[:, 0], axis=0)
        row_diff_ref2first = row_diff_ref2first*100 # convert to milimeter
        
        row_diff_ref2base = row_diff_ref2first.iloc[::-1].cumsum(axis=0)[::-1]
        
        fig, ax = mlcw_obj.quick_plot(df=row_diff_ref2base, station_label=select_station, figsize=(12, 6))
        
        visualize.save_figure(fig=fig, savepath=f"figs_checkMLCW\\{select_station}_temp.png")
        plt.close()
    except Exception as e:
        print(select_station, e)
        pass

# %% [raw]
# # select_station = available_stations[2]
# for select_station in tqdm(available_stations):
#     try:
#         fig, ax = mlcw_obj.quick_plot(station=select_station, value_type="ref2base", station_label=select_station, end_date="2022", figsize=(12,6), reference_to_first_measurement=True)
#         visualize.save_figure(fig=fig, savepath=f"figs_checkMLCW\\{select_station}_orig.png")
#         plt.close()
#     except Exception as e:
#         print(select_station, e)
#         pass

# %% [raw]
# h5_fpath = "20250305_CLEANED_MLCW_monthly_v3.h5"
# # initiate MLCW class object
# mlcw_obj = MLCW(h5_fpath=h5_fpath)
# mlcw_data, mlcw_metadata = mlcw_obj.get_data()
# available_stations = mlcw_obj.list_stations()
# available_stations[:5]

# %%
mlcw_obj.list_structure(mlcw_data)

# %% [raw]
# # select_station = available_stations[2]
# for select_station in tqdm(available_stations):
#     try:
#         fig, ax = mlcw_obj.quick_plot(station=select_station, value_type="cleaned_ref2base", station_label=select_station, start_date="2014", end_date="2022", figsize=(12,6), reference_to_first_measurement=True)
#         visualize.save_figure(fig=fig, savepath=f"figs_checkMLCW\\{select_station}_cleaned.png")
#         plt.close()
#     except Exception as e:
#         print(select_station, e)
#         pass

# %% [raw]
# folder = r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\1_PrepareDatasets\1_MLCWs\pca_result_n"
# excel_files = glob(os.path.join(folder, "*.xlsx"))
#
# select_file = excel_files[0]
# for select_file in excel_files:
#     select_station = os.path.basename(select_file).split("_")[0]
#     df = pd.read_excel(select_file, parse_dates=[0], index_col=[0])
#     df = df.T
#     df = df/10
#
#     fig, ax = mlcw_obj.quick_plot(df=df, start_date="2014", end_date="2022", reference_to_first_measurement=True, station_label=select_station, figsize=(12,6))
#     visualize.save_figure(fig=fig, savepath=f"figs_checkMLCW\\{select_station}_orig_cleaned.png")
#     plt.close()

# %% [raw]
# def get_statistics(series):
#     stats = series.describe()
#     mean = stats.loc["mean"]
#     median = stats.loc["50%"]
#     stdev = stats.loc["std"]
#     min_val = stats.loc["min"]
#     max_val = stats.loc["max"]
#     coeff_var = stdev / mean
#     return mean, median, stdev, coeff_var, min_val, max_val
#
# for select_station in tqdm(available_stations):
#
#     cache = {"Rings": [], "Mean": [], "Median": [], "Stdev": [], "CV": [], "Min": [], "Max": []}
#
#     original_df = mlcw_obj.build_dataframe(station=select_station, value_type="original")
#     original_df.columns = pd.to_datetime(original_df.columns)
#     original_df = original_df.sort_index(axis=1)
#     original_df = original_df.loc[:, :"2022"]
#     model_df = mlcw_obj.build_dataframe(station=select_station, value_type="model_original")
#     if original_df.shape == model_df.shape:
#         diff_in_mm = (original_df - model_df) * 1000
#         rings = diff_in_mm.index
#         for ring in rings:
#             diff_by_ring = diff_in_mm.loc[ring, :]
#             for key, value in zip(cache.keys(), [ring] + list(get_statistics(diff_by_ring))):
#                 cache[key].append(value)
#
#         diff_summary = pd.DataFrame(cache)
#         data_io.save_df_to_excel(
#             df_to_save=diff_summary, filepath="original_model_diffence.xlsx", sheet_name=select_station
#         )
#     else:
#         print(f"Encounter problem at {select_station}")
