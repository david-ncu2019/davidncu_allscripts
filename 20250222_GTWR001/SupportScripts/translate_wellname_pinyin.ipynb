# %%
import pandas as pd
from pypinyin import Style, pinyin


def convert_to_pinyin_without_tones(text):
    """
    Converts the given Chinese text to Pinyin without tone marks.

    Args:
        text (str): The Chinese text to convert.

    Returns:
        str: The Pinyin representation without tones.
    """
    try:
        # Convert to Pinyin without tones (Style.NORMAL) and handle as words
        pinyin_list = pinyin(text, style=Style.NORMAL, heteronym=False)

        # Extract the first (and usually only) pinyin syllable from each inner list
        # This gets the complete syllable, not just the first character
        return "".join([sublist[0] for sublist in pinyin_list])

    except Exception as e:
        return f"Conversion error: {str(e)}"

# %% [raw]
# # Example usage with a pandas Series
# # Create a sample pandas Series with Chinese text
# data = pd.Series(["你好，世界", "谢谢", "再见", "北京欢迎你"])
#
# # Apply the Pinyin conversion function to each element in the Series
# pinyin_series = data.apply(convert_to_pinyin_without_tones)
#
# # Display the original and Pinyin Series
# print("Original Series:")
# print(data)
# print("\nPinyin Series (without tones):")
# print(pinyin_series)
#
# # Let's also test individual conversions to see the improvement
# print("\n" + "=" * 50)
# print("Individual conversion examples:")
# print("=" * 50)
#
# test_phrases = ["你好", "世界", "谢谢", "北京"]
# for phrase in test_phrases:
#     result = convert_to_pinyin_without_tones(phrase)
#     print(f"'{phrase}' → '{result}'")

# %%
from appgeopy import *
from my_packages import *

fpath = r"E:\SUBSIDENCE_PROJECT_DATA\地陷資料整理\地陷井\well_meta_MLCW_Choushui_WGS84_elev.shp"
gdf = gpd.read_file(fpath)
gdf.head(5), gdf.columns
# Out:
# (  WellIdenti 檔案名 CountyName TownName   X_TWD97    Y_TWD97     POINT_X  \
#  0   WSYL10G1  海豐         雲林      麥寮鄉  171149.0  2629139.0  120.226406
#  1   WSYL13G1  建陽         雲林      四湖鄉  163505.0  2614756.0  120.152257
#  2   WSYL15G1  金湖         雲林      口湖鄉  163597.0  2608018.0  120.153549
#  3   WSYL14G1  東光         雲林      四湖鄉  175782.0  2616754.0  120.272477
#  4   WSYL32G1  北辰         雲林      北港鎮  178860.0  2608238.0  120.303054
#
#       POINT_Y  RASTERVALU                    geometry
#  0  23.764337           1  POINT (120.22641 23.76434)
#  1  23.634080           3  POINT (120.15226 23.63408)
#  2  23.573247           2  POINT (120.15355 23.57325)
#  3  23.652731          10  POINT (120.27248 23.65273)
#  4  23.575976          16  POINT (120.30305 23.57598)  ,
#  Index(['WellIdenti', '檔案名', 'CountyName', 'TownName', 'X_TWD97', 'Y_TWD97',
#         'POINT_X', 'POINT_Y', 'RASTERVALU', 'geometry'],
#        dtype='object'))

# %%
translated_wellname = gdf.loc[:, "檔案名"].apply(
    convert_to_pinyin_without_tones
)
translated_wellname = translated_wellname.apply(lambda x: x.capitalize())

translated_towname = gdf.loc[:, "TownName"].apply(
    convert_to_pinyin_without_tones
)
translated_towname = translated_towname.apply(lambda x: x.capitalize())

gdf.insert(loc=2, column="StationName", value=translated_wellname)
gdf.insert(loc=5, column="TownName_EN", value=translated_towname)

# %%
gdf = gdf.rename(
    {"POINT_X": "LONG", "POINT_Y": "LAT", "RASTERVALU": "Elev"}, axis=1
)

# %% [raw]
# gdf.to_excel("MLCW_info_english.xlsx", index=False)

# %%
gdf
# Out:
#    WellIdenti 檔案名 StationName CountyName TownName     TownName_EN   X_TWD97  \
# 0    WSYL10G1  海豐     Haifeng         雲林      麥寮鄉    Mailiaoxiang  171149.0
# 1    WSYL13G1  建陽    Jianyang         雲林      四湖鄉       Sihuxiang  163505.0
# 2    WSYL15G1  金湖       Jinhu         雲林      口湖鄉      Kouhuxiang  163597.0
# 3    WSYL14G1  東光   Dongguang         雲林      四湖鄉       Sihuxiang  175782.0
# 4    WSYL32G1  北辰     Beichen         雲林      北港鎮     Beigangzhen  178860.0
# 5    WSYL17G1  燦林      Canlin         雲林      水林鄉    Shuilinxiang  173087.0
# 6    WSYL16G1  宜梧        Yiwu         雲林      口湖鄉      Kouhuxiang  167840.0
# 7    WSYL28G1  拯民    Zhengmin         雲林      虎尾鎮       Huweizhen  189570.0
# 8    WSYL25G1  宏崙     Honglun         雲林      土庫鎮        Tukuzhen  183488.0
# 9    WSYL30G1  鎮南     Zhennan         雲林      斗六市       Douliushi  202938.0
# 10   WSYL31G1  嘉興     Jiaxing         雲林      大埤鄉       Dapixiang  194874.0
# 11   WSYL09G1  豐安      Fengan         雲林      麥寮鄉    Mailiaoxiang  171858.0
# 12   WSYL27G1  光復     Guangfu         雲林      虎尾鎮       Huweizhen  189083.0
# 13   WSYL26G1  虎尾       Huwei         雲林      虎尾鎮       Huweizhen  192040.0
# 14   WSYL11G1  新興     Xinxing         雲林      台西鄉      Taixixiang  170720.0
# 15   WSYL18G1  二崙       Erlun         雲林      二崙鄉      Erlunxiang  190428.0
# 16   WSYL19G1  豐榮    Fengrong         雲林      崙背鄉     Lunbeixiang  179784.0
# 17   WSYL20G1  元長   Yuanzhang         雲林      元長鄉  Yuanzhangxiang  179484.0
# 18   WSYL21G1  客厝       Kecuo         雲林      元長鄉  Yuanzhangxiang  182074.0
# 19   WSYL22G1  內寮     Neiliao         雲林      元長鄉  Yuanzhangxiang  184141.0
# 20   WSYL23G1  土庫        Tuku         雲林      土庫鎮        Tukuzhen  187771.0
# 21   WSYL24G1  秀潭      Xiutan         雲林      土庫鎮        Tukuzhen  183651.0
# 22   WSYL29G1  龍岩     Longyan         雲林      褒忠鄉   Baozhongxiang  179249.0
# 23   WSCH01G1  新街      Xinjie         彰化      芳苑鄉   Fangyuanxiang  179967.0
# 24   WSCH02G1  西港      Xigang         彰化      大城鄉    Dachengxiang  177633.0
# 25   WSCH03G1  興華     Xinghua         彰化      二林鎮       Erlinzhen  188363.0
# 26   WSCH04G1  新生    Xinsheng         彰化      二林鎮       Erlinzhen  188341.0
# 27   WSCH07G1  僑義      Qiaoyi         彰化      溪州鄉     Xizhouxiang  196959.0
# 28   WSCH06G1  溪州      Xizhou         彰化      溪州鄉     Xizhouxiang  198873.0
# 29   WSCH08G1  竹塘     Zhutang         彰化      竹塘鄉    Zhutangxiang  191773.0
# 30   WSCH05G1  湖南       Hunan         彰化      溪湖鎮        Xihuzhen  196984.0
# 31   WSYL12G1  崙豐     Lunfeng         雲林      台西鄉      Taixixiang  169452.0
#
#       Y_TWD97        LONG        LAT  Elev                    geometry
# 0   2629139.0  120.226406  23.764337     1  POINT (120.22641 23.76434)
# 1   2614756.0  120.152257  23.634080     3  POINT (120.15226 23.63408)
# 2   2608018.0  120.153549  23.573247     2  POINT (120.15355 23.57325)
# 3   2616754.0  120.272477  23.652731    10  POINT (120.27248 23.65273)
# 4   2608238.0  120.303054  23.575976    16  POINT (120.30305 23.57598)
# 5   2608156.0  120.246505  23.574971     9   POINT (120.2465 23.57497)
# 6   2604973.0  120.195280  23.545974     3  POINT (120.19528 23.54597)
# 7   2622974.0  120.407374  23.709470    24  POINT (120.40737 23.70947)
# 8   2620464.0  120.347845  23.686566    17  POINT (120.34784 23.68657)
# 9   2621719.0  120.538508  23.698584    56  POINT (120.53851 23.69858)
# 10  2616145.0  120.459641  23.647997    32    POINT (120.45964 23.648)
# 11  2631893.0  120.233215  23.789237     4  POINT (120.23322 23.78924)
# 12  2626507.0  120.402453  23.741352    22  POINT (120.40245 23.74135)
# 13  2623605.0  120.431572  23.715258    25  POINT (120.43157 23.71526)
# 14  2626355.0  120.222347  23.739179     4  POINT (120.22235 23.73918)
# 15  2629865.0  120.415511  23.771723    28  POINT (120.41551 23.77172)
# 16  2632015.0  120.310981  23.790706    10  POINT (120.31098 23.79071)
# 17  2616803.0  120.308761  23.653340    10  POINT (120.30876 23.65334)
# 18  2613831.0  120.334284  23.626615    14  POINT (120.33428 23.62662)
# 19  2611722.0  120.354634  23.607658    13  POINT (120.35463 23.60766)
# 20  2620610.0  120.389832  23.688056    23  POINT (120.38983 23.68806)
# 21  2617396.0  120.349580  23.658871    14  POINT (120.34958 23.65887)
# 22  2624490.0  120.306091  23.722737    13  POINT (120.30609 23.72274)
# 23  2644391.0  120.312187  23.902458     8  POINT (120.31219 23.90246)
# 24  2639733.0  120.289495  23.860296     3   POINT (120.28949 23.8603)
# 25  2643201.0  120.394692  23.892060    18  POINT (120.39469 23.89206)
# 26  2648279.0  120.394263  23.937909    12  POINT (120.39426 23.93791)
# 27  2637815.0  120.479301  23.843737    34   POINT (120.4793 23.84374)
# 28  2638772.0  120.498057  23.852440    38  POINT (120.49806 23.85244)
# 29  2639649.0  120.428320  23.860116    27  POINT (120.42832 23.86012)
# 30  2649404.0  120.479128  23.948378    19  POINT (120.47913 23.94838)
# 31  2624162.0  120.210029  23.719315     2  POINT (120.21003 23.71931)

# %%
mlcw_data_fld = r"D:\1000_SCRIPTS\001_PreQE_Scripts\MultiLayerCompactionMonitoringWells\MLCW_Data_Extraction"

cache = []

wellcode_list = gdf.iloc[:, 0]

# select_wellcode = wellcode_list[0]
for select_wellcode in wellcode_list:

    file_byWellCode = glob(
        os.path.join(mlcw_data_fld, f"*{select_wellcode}*.xlsx")
    )[0]

    file_byWellCode_df = pd.read_excel(file_byWellCode)

    bottom_depth = file_byWellCode_df["BOTTOM"].max()
    cache.append(bottom_depth)

gdf.insert(loc=len(gdf.columns)-1, column="BottomDepth", value=cache)

# %%
gdf.to_csv("MLCW_info_english.csv", index=False)
# Out:
#    WellIdenti 檔案名 StationName CountyName TownName     TownName_EN   X_TWD97  \
# 0    WSYL10G1  海豐     Haifeng         雲林      麥寮鄉    Mailiaoxiang  171149.0
# 1    WSYL13G1  建陽    Jianyang         雲林      四湖鄉       Sihuxiang  163505.0
# 2    WSYL15G1  金湖       Jinhu         雲林      口湖鄉      Kouhuxiang  163597.0
# 3    WSYL14G1  東光   Dongguang         雲林      四湖鄉       Sihuxiang  175782.0
# 4    WSYL32G1  北辰     Beichen         雲林      北港鎮     Beigangzhen  178860.0
# 5    WSYL17G1  燦林      Canlin         雲林      水林鄉    Shuilinxiang  173087.0
# 6    WSYL16G1  宜梧        Yiwu         雲林      口湖鄉      Kouhuxiang  167840.0
# 7    WSYL28G1  拯民    Zhengmin         雲林      虎尾鎮       Huweizhen  189570.0
# 8    WSYL25G1  宏崙     Honglun         雲林      土庫鎮        Tukuzhen  183488.0
# 9    WSYL30G1  鎮南     Zhennan         雲林      斗六市       Douliushi  202938.0
# 10   WSYL31G1  嘉興     Jiaxing         雲林      大埤鄉       Dapixiang  194874.0
# 11   WSYL09G1  豐安      Fengan         雲林      麥寮鄉    Mailiaoxiang  171858.0
# 12   WSYL27G1  光復     Guangfu         雲林      虎尾鎮       Huweizhen  189083.0
# 13   WSYL26G1  虎尾       Huwei         雲林      虎尾鎮       Huweizhen  192040.0
# 14   WSYL11G1  新興     Xinxing         雲林      台西鄉      Taixixiang  170720.0
# 15   WSYL18G1  二崙       Erlun         雲林      二崙鄉      Erlunxiang  190428.0
# 16   WSYL19G1  豐榮    Fengrong         雲林      崙背鄉     Lunbeixiang  179784.0
# 17   WSYL20G1  元長   Yuanzhang         雲林      元長鄉  Yuanzhangxiang  179484.0
# 18   WSYL21G1  客厝       Kecuo         雲林      元長鄉  Yuanzhangxiang  182074.0
# 19   WSYL22G1  內寮     Neiliao         雲林      元長鄉  Yuanzhangxiang  184141.0
# 20   WSYL23G1  土庫        Tuku         雲林      土庫鎮        Tukuzhen  187771.0
# 21   WSYL24G1  秀潭      Xiutan         雲林      土庫鎮        Tukuzhen  183651.0
# 22   WSYL29G1  龍岩     Longyan         雲林      褒忠鄉   Baozhongxiang  179249.0
# 23   WSCH01G1  新街      Xinjie         彰化      芳苑鄉   Fangyuanxiang  179967.0
# 24   WSCH02G1  西港      Xigang         彰化      大城鄉    Dachengxiang  177633.0
# 25   WSCH03G1  興華     Xinghua         彰化      二林鎮       Erlinzhen  188363.0
# 26   WSCH04G1  新生    Xinsheng         彰化      二林鎮       Erlinzhen  188341.0
# 27   WSCH07G1  僑義      Qiaoyi         彰化      溪州鄉     Xizhouxiang  196959.0
# 28   WSCH06G1  溪州      Xizhou         彰化      溪州鄉     Xizhouxiang  198873.0
# 29   WSCH08G1  竹塘     Zhutang         彰化      竹塘鄉    Zhutangxiang  191773.0
# 30   WSCH05G1  湖南       Hunan         彰化      溪湖鎮        Xihuzhen  196984.0
# 31   WSYL12G1  崙豐     Lunfeng         雲林      台西鄉      Taixixiang  169452.0
#
#       Y_TWD97        LONG        LAT  Elev  BottomDepth  \
# 0   2629139.0  120.226406  23.764337     1        200.0
# 1   2614756.0  120.152257  23.634080     3        200.0
# 2   2608018.0  120.153549  23.573247     2        200.0
# 3   2616754.0  120.272477  23.652731    10        300.0
# 4   2608238.0  120.303054  23.575976    16        320.0
# 5   2608156.0  120.246505  23.574971     9        300.0
# 6   2604973.0  120.195280  23.545974     3        300.0
# 7   2622974.0  120.407374  23.709470    24        327.0
# 8   2620464.0  120.347845  23.686566    17        340.0
# 9   2621719.0  120.538508  23.698584    56        300.0
# 10  2616145.0  120.459641  23.647997    32        300.0
# 11  2631893.0  120.233215  23.789237     4        300.0
# 12  2626507.0  120.402453  23.741352    22        300.0
# 13  2623605.0  120.431572  23.715258    25        300.0
# 14  2626355.0  120.222347  23.739179     4        300.0
# 15  2629865.0  120.415511  23.771723    28        300.0
# 16  2632015.0  120.310981  23.790706    10        300.0
# 17  2616803.0  120.308761  23.653340    10        300.0
# 18  2613831.0  120.334284  23.626615    14        300.0
# 19  2611722.0  120.354634  23.607658    13        300.0
# 20  2620610.0  120.389832  23.688056    23        300.0
# 21  2617396.0  120.349580  23.658871    14        300.0
# 22  2624490.0  120.306091  23.722737    13        300.0
# 23  2644391.0  120.312187  23.902458     8        300.0
# 24  2639733.0  120.289495  23.860296     3        300.0
# 25  2643201.0  120.394692  23.892060    18        300.0
# 26  2648279.0  120.394263  23.937909    12        300.0
# 27  2637815.0  120.479301  23.843737    34        300.0
# 28  2638772.0  120.498057  23.852440    38        300.0
# 29  2639649.0  120.428320  23.860116    27        300.0
# 30  2649404.0  120.479128  23.948378    19        300.0
# 31  2624162.0  120.210029  23.719315     2        305.8
#
#                       geometry
# 0   POINT (120.22641 23.76434)
# 1   POINT (120.15226 23.63408)
# 2   POINT (120.15355 23.57325)
# 3   POINT (120.27248 23.65273)
# 4   POINT (120.30305 23.57598)
# 5    POINT (120.2465 23.57497)
# 6   POINT (120.19528 23.54597)
# 7   POINT (120.40737 23.70947)
# 8   POINT (120.34784 23.68657)
# 9   POINT (120.53851 23.69858)
# 10    POINT (120.45964 23.648)
# 11  POINT (120.23322 23.78924)
# 12  POINT (120.40245 23.74135)
# 13  POINT (120.43157 23.71526)
# 14  POINT (120.22235 23.73918)
# 15  POINT (120.41551 23.77172)
# 16  POINT (120.31098 23.79071)
# 17  POINT (120.30876 23.65334)
# 18  POINT (120.33428 23.62662)
# 19  POINT (120.35463 23.60766)
# 20  POINT (120.38983 23.68806)
# 21  POINT (120.34958 23.65887)
# 22  POINT (120.30609 23.72274)
# 23  POINT (120.31219 23.90246)
# 24   POINT (120.28949 23.8603)
# 25  POINT (120.39469 23.89206)
# 26  POINT (120.39426 23.93791)
# 27   POINT (120.4793 23.84374)
# 28  POINT (120.49806 23.85244)
# 29  POINT (120.42832 23.86012)
# 30  POINT (120.47913 23.94838)
# 31  POINT (120.21003 23.71931)
