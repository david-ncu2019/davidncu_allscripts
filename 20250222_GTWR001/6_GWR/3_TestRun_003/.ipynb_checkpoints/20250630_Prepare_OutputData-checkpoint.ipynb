# %%
from my_packages import *
from appgeopy import *

# %%
top_folder = "GWR_Prediction_Output/"
output_folder_byLayer = glob(os.path.join(top_folder, "Layer*"))
output_folder_byLayer
# Out:
# ['GWR_Prediction_Output\\Layer_1',
#  'GWR_Prediction_Output\\Layer_2',
#  'GWR_Prediction_Output\\Layer_3',
#  'GWR_Prediction_Output\\Layer_4']

# %%
# # select_folder = output_folder_byLayer[0]
for select_folder in tqdm(output_folder_byLayer):
    layer_name = os.path.basename(select_folder)
    output_df = pd.DataFrame(data=None, index=None)
    
    for i in trange(1, 67):
    # i = 1
        search_key= f"*_time{i}_*"
        found_file = glob(os.path.join(select_folder, search_key))[0]
        df = pd.read_csv(found_file)
        df = df.drop(labels=["X_TWD97.1", "Y_TWD97.1"], axis=1)
        df["prediction_std"] = np.sqrt(df["prediction_var"])
        df["monthly"] = i
        pointkey_arr = [f"X{int(x*1000)}Y{int(y*1000)}" for x,y in zip(df["X_TWD97"], df["Y_TWD97"])]
        df.insert(loc=0, column="PointKey", value=pointkey_arr)
        output_df = pd.concat([output_df, df], ignore_index=True)
    
    output_df.to_feather(os.path.join(top_folder, f"gwr_prediction_{layer_name}.feather"))
# Out:
#   0%|          | 0/66 [00:00<?, ?it/s]

# %%
output_df
# Out:
#                       PointKey        X_TWD97       Y_TWD97  Intercept_coef  \
# 0        X162648119Y2595992857  162648.119363  2.595993e+06       -1.371919
# 1        X162848119Y2595992857  162848.119363  2.595993e+06       -1.372375
# 2        X163048119Y2595992857  163048.119363  2.595993e+06       -1.372838
# 3        X162648119Y2596192857  162648.119363  2.596193e+06       -1.370159
# 4        X162848119Y2596192857  162848.119363  2.596193e+06       -1.370609
# ...                        ...            ...           ...             ...
# 3937423  X197848119Y2676592857  197848.119363  2.676593e+06        2.306734
# 3937424  X198048119Y2676592857  198048.119363  2.676593e+06        2.293890
# 3937425  X198248119Y2676592857  198248.119363  2.676593e+06        2.281081
# 3937426  X198448119Y2676592857  198448.119363  2.676593e+06        2.268309
# 3937427  X197848119Y2676792857  197848.119363  2.676793e+06        2.312369
#
#          CUMDISP_coef  prediction  prediction_var  prediction_std  monthly
# 0           -0.042356   -0.703469        1.874933        1.369282        1
# 1           -0.042377   -0.742346        1.910161        1.382086        1
# 2           -0.042398   -0.773551        1.939890        1.392799        1
# 3           -0.042284   -0.763771        1.932343        1.390087        1
# 4           -0.042305   -0.767913        1.935687        1.391290        1
# ...               ...         ...             ...             ...      ...
# 3937423      0.093289    0.660545      108.534119       10.417971       66
# 3937424      0.093174    1.093554      109.492296       10.463857       66
# 3937425      0.093059    1.411265      110.221769       10.498656       66
# 3937426      0.092945    1.932510      111.463379       10.557622       66
# 3937427      0.093347    1.052136      109.395881       10.459249       66
#
# [3937428 rows x 9 columns]
