# %% [raw]
# from appgeopy import *
# from my_packages import *

# %% [raw]
# validation_df = pd.read_csv("model_regpoints_2.csv")
# prediction_df = pd.read_csv("model_regpoints_predict_2.csv")

# %% [raw]
# validation_df["dep_pred"] = (
#     validation_df["indep_1"] * prediction_df["indep_1"]
#     + validation_df["indep_2"] * prediction_df["indep_2"]
#     + prediction_df["Intercept"]
# )

# %% [raw]
# from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error
#
# mae = mean_absolute_error(y_true=validation_df["dep"], y_pred=validation_df["dep_pred"])
# rmse = root_mean_squared_error(y_true=validation_df["dep"], y_pred=validation_df["dep_pred"])
# r2 = r2_score(y_true=validation_df["dep"], y_pred=validation_df["dep_pred"])

# %% [raw]
# mae, rmse, r2

# %% [raw]
# validation_df
