# %% [raw]
# #!/usr/bin/env python
# # coding: utf-8
#
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from scipy.optimize import least_squares, differential_evolution
# from sklearn.metrics import r2_score
#
# def generate_damped_synthetic_data(
#     start_date,
#     end_date,
#     initial_amplitude,
#     decay_constant,
#     frequency,
#     phase,
#     noise_variance,
#     linear_trend=0
# ):
#     """
#     Generate synthetic damped sinusoidal data.
#
#     Parameters:
#     - start_date, end_date: Date range
#     - initial_amplitude: Starting amplitude A
#     - decay_constant: Time constant τ (larger = slower decay)
#     - frequency: Oscillation frequency (cycles per year)
#     - phase: Phase shift in radians
#     - noise_variance: Random noise level
#     - linear_trend: Optional linear trend
#
#     Formula: A * exp(-t/τ) * sin(2πft + φ) + trend + noise
#     """
#     dates = pd.date_range(start=start_date, end=end_date, freq="D")
#     np.random.seed(42)
#
#     # Time in years from start
#     t_years = (dates - dates[0]).days / 365.25
#
#     # Damped sinusoidal component
#     damped_sine = initial_amplitude * np.exp(-t_years / decay_constant) * \
#                   np.sin(2 * np.pi * frequency * t_years + phase)
#
#     # Linear trend component
#     trend_component = linear_trend * t_years
#
#     # Random noise
#     noise_component = np.random.normal(scale=noise_variance, size=len(dates))
#
#     # Combine components
#     data = damped_sine + trend_component + noise_component
#
#     return pd.DataFrame({"date": dates, "value": data}).set_index("date")
#
# def damped_sine_model(t, params):
#     """
#     Damped sine wave model: A * exp(-t/τ) * sin(2πft + φ) + c
#
#     Parameters:
#     - t: time array
#     - params: [amplitude, decay_constant, frequency, phase, offset]
#     """
#     A, tau, f, phi, c = params
#     return A * np.exp(-t / tau) * np.sin(2 * np.pi * f * t + phi) + c
#
# def objective_function(params, t, observed_values):
#     """Objective function for optimization"""
#     predicted = damped_sine_model(t, params)
#     residuals = observed_values - predicted
#     return residuals
#
# def fit_damped_sine_wave(time_series_data, initial_guess=None):
#     """
#     Fit damped sine wave to time series data using optimization.
#
#     Parameters:
#     - time_series_data: pandas DataFrame with datetime index and 'value' column
#     - initial_guess: [A, tau, f, phi, c] initial parameter estimates
#
#     Returns:
#     - fitted_params: optimized parameters
#     - fitted_signal: reconstructed signal
#     - fit_metrics: R² and RMSE
#     """
#     # Prepare data
#     dates = time_series_data.index
#     t_years = (dates - dates[0]).days / 365.25  # Time in years
#     observed_values = time_series_data['value'].values
#
#     # Default initial guess if not provided
#     if initial_guess is None:
#         amplitude_guess = np.std(observed_values) * 2
#         decay_guess = (t_years[-1] - t_years[0]) / 2  # Half the time span
#         freq_guess = 1.0  # 1 cycle per year
#         phase_guess = 0.0
#         offset_guess = np.mean(observed_values)
#         initial_guess = [amplitude_guess, decay_guess, freq_guess, phase_guess, offset_guess]
#
#     # Parameter bounds: [A, tau, f, phi, c]
#     bounds = [
#         (-100, 100),    # Amplitude
#         (0.1, 20),      # Decay constant (positive, reasonable range)
#         (0.1, 10),      # Frequency (0.1 to 10 cycles per year)
#         (-2*np.pi, 2*np.pi),  # Phase
#         (-100, 100)     # Offset
#     ]
#
#     # Use differential evolution for global optimization
#     result = differential_evolution(
#         lambda params: np.sum(objective_function(params, t_years, observed_values)**2),
#         bounds,
#         seed=42,
#         maxiter=1000
#     )
#
#     fitted_params = result.x
#     fitted_signal = damped_sine_model(t_years, fitted_params)
#
#     # Calculate fit metrics
#     r2 = r2_score(observed_values, fitted_signal)
#     rmse = np.sqrt(np.mean((observed_values - fitted_signal)**2))
#
#     fit_metrics = {'R²': r2, 'RMSE': rmse}
#
#     return fitted_params, fitted_signal, fit_metrics
#
# def analyze_damped_signal(time_series_data):
#     """
#     Complete analysis of damped sinusoidal signal.
#     """
#     print("Fitting damped sine wave model...")
#     fitted_params, fitted_signal, metrics = fit_damped_sine_wave(time_series_data)
#
#     # Extract parameters
#     A, tau, f, phi, c = fitted_params
#
#     print(f"\nFitted Parameters:")
#     print(f"Amplitude (A): {A:.3f}")
#     print(f"Decay constant (τ): {tau:.3f} years")
#     print(f"Frequency (f): {f:.3f} cycles/year")
#     print(f"Phase (φ): {phi:.3f} radians")
#     print(f"Offset (c): {c:.3f}")
#     print(f"\nFit Quality:")
#     print(f"R²: {metrics['R²']:.4f}")
#     print(f"RMSE: {metrics['RMSE']:.4f}")
#
#     return fitted_params, fitted_signal, metrics
#
# def plot_results(original_data, fitted_signal, title="Damped Sine Wave Analysis"):
#     """
#     Plot original data vs fitted model.
#     """
#     fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
#
#     # Main plot
#     ax1.plot(original_data.index, original_data['value'], 'k-', label='Original Data', alpha=0.7)
#     ax1.plot(original_data.index, fitted_signal, 'r-', label='Fitted Model', linewidth=2)
#     ax1.set_ylabel('Value')
#     ax1.set_title(title)
#     ax1.legend()
#     ax1.grid(True, alpha=0.3)
#
#     # Residuals
#     residuals = original_data['value'].values - fitted_signal
#     ax2.plot(original_data.index, residuals, 'b-', alpha=0.7)
#     ax2.axhline(y=0, color='k', linestyle='--', alpha=0.5)
#     ax2.set_ylabel('Residuals')
#     ax2.set_xlabel('Date')
#     ax2.grid(True, alpha=0.3)
#
#     plt.tight_layout()
#     return fig
#
# # Example usage
# if __name__ == "__main__":
#     # Generate synthetic damped sine wave data
#     print("Generating synthetic damped sine wave data...")
#     synthetic_data = generate_damped_synthetic_data(
#         start_date="2020-01-01",
#         end_date="2024-12-31",
#         initial_amplitude=5.0,      # Starting amplitude
#         decay_constant=1.0,         # Decay over 2 years
#         frequency=1.5,              # 1.5 cycles per year
#         phase=np.pi/4,              # Phase shift
#         noise_variance=0.5,         # Noise level
#         linear_trend=0.1            # Small upward trend
#     )
#
#     print(f"Generated {len(synthetic_data)} data points")
#     print(f"Date range: {synthetic_data.index[0].date()} to {synthetic_data.index[-1].date()}")
#
#     # Analyze the data
#     fitted_params, fitted_signal, metrics = analyze_damped_signal(synthetic_data)
#
#     # Plot results
#     fig = plot_results(synthetic_data, fitted_signal, "Damped Sine Wave: Original vs Fitted")
#     plt.show()
#
#     # Compare with known parameters
#     print(f"\nComparison with known parameters:")
#     print(f"True amplitude: 5.0, Fitted: {fitted_params[0]:.3f}")
#     print(f"True decay constant: 2.0, Fitted: {fitted_params[1]:.3f}")
#     print(f"True frequency: 1.5, Fitted: {fitted_params[2]:.3f}")
#     print(f"True phase: {np.pi/4:.3f}, Fitted: {fitted_params[3]:.3f}")

# %% [raw]
# #!/usr/bin/env python
# # coding: utf-8
#
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from scipy.optimize import least_squares, differential_evolution
# from scipy.signal import find_peaks, welch
# from scipy.fft import fft, fftfreq
# from sklearn.metrics import r2_score
# import warnings
# warnings.filterwarnings('ignore')
#
# class SineWaveFitter:
#     """
#     Enhanced sine wave fitting tool that can handle various types of sine wave data.
#     Supports pure sine waves, damped sine waves, and multi-component signals.
#     """
#
#     def __init__(self, sampling_rate='auto'):
#         """
#         Initialize the sine wave fitter.
#
#         Parameters:
#         - sampling_rate: str or float
#             'auto' - automatically detect from data
#             'hourly', 'daily', 'weekly', 'monthly', 'yearly' - predefined rates
#             float - custom samples per year (e.g., 365.25 for daily)
#         """
#         self.fitted_params = None
#         self.fitted_signal = None
#         self.fit_metrics = None
#         self.model_type = None
#         self.sampling_rate = sampling_rate
#         self.time_unit = None
#         self.samples_per_year = None
#
#     def _detect_and_set_sampling_rate(self, time_series_data):
#         """
#         Detect or set the sampling rate from data or user specification.
#         """
#         if self.sampling_rate == 'auto':
#             # Auto-detect from data
#             dates = time_series_data.index
#             if len(dates) < 2:
#                 raise ValueError("Need at least 2 data points to detect sampling rate")
#
#             # Calculate median time difference
#             time_diffs = [(dates[i+1] - dates[i]).total_seconds() for i in range(min(10, len(dates)-1))]
#             median_diff_seconds = np.median(time_diffs)
#
#             # Classify sampling rate
#             if median_diff_seconds <= 3700:  # ≤ ~1 hour
#                 self.sampling_rate = 'hourly'
#                 self.samples_per_year = 365.25 * 24
#                 self.time_unit = 'hours'
#             elif median_diff_seconds <= 86500:  # ≤ ~1 day
#                 self.sampling_rate = 'daily'
#                 self.samples_per_year = 365.25
#                 self.time_unit = 'days'
#             elif median_diff_seconds <= 604900:  # ≤ ~1 week
#                 self.sampling_rate = 'weekly'
#                 self.samples_per_year = 52.18
#                 self.time_unit = 'weeks'
#             elif median_diff_seconds <= 2678400:  # ≤ ~1 month
#                 self.sampling_rate = 'monthly'
#                 self.samples_per_year = 12
#                 self.time_unit = 'months'
#             else:
#                 self.sampling_rate = 'yearly'
#                 self.samples_per_year = 1
#                 self.time_unit = 'years'
#
#         elif isinstance(self.sampling_rate, str):
#             # User-specified predefined rates
#             rate_map = {
#                 'hourly': (365.25 * 24, 'hours'),
#                 'daily': (365.25, 'days'),
#                 'weekly': (52.18, 'weeks'),
#                 'monthly': (12, 'months'),
#                 'yearly': (1, 'years')
#             }
#             if self.sampling_rate not in rate_map:
#                 raise ValueError(f"Unknown sampling rate: {self.sampling_rate}")
#
#             self.samples_per_year, self.time_unit = rate_map[self.sampling_rate]
#
#         elif isinstance(self.sampling_rate, (int, float)):
#             # User-specified custom rate (samples per year)
#             self.samples_per_year = self.sampling_rate
#             self.time_unit = 'custom_units'
#
#         else:
#             raise ValueError("sampling_rate must be 'auto', a predefined string, or a number")
#
#     def _convert_to_normalized_time(self, time_series_data):
#         """
#         Convert datetime index to normalized time units based on sampling rate.
#         Returns time array in years from start.
#         """
#         dates = time_series_data.index
#         time_seconds = (dates - dates[0]).total_seconds()
#
#         # Convert to years (our standard unit for calculations)
#         time_years = time_seconds / (365.25 * 24 * 3600)
#
#         return time_years
#
#     def preprocess_data(self, time_series_data, remove_trend=True, smooth_window=None):
#         """
#         Preprocess time series data for better fitting.
#
#         Parameters:
#         - time_series_data: DataFrame with datetime index and 'value' column
#         - remove_trend: Whether to remove linear trend
#         - smooth_window: Optional smoothing window size
#         """
#         data = time_series_data.copy()
#
#         # Remove linear trend if requested
#         if remove_trend:
#             t_numeric = np.arange(len(data))
#             trend_coef = np.polyfit(t_numeric, data['value'], 1)
#             trend = np.polyval(trend_coef, t_numeric)
#             data['value'] = data['value'] - trend
#             data['trend'] = trend
#
#         # Optional smoothing
#         if smooth_window:
#             data['value'] = data['value'].rolling(window=smooth_window, center=True).mean()
#             data = data.dropna()
#
#         return data
#         """
#         Preprocess time series data for better fitting.
#
#         Parameters:
#         - time_series_data: DataFrame with datetime index and 'value' column
#         - remove_trend: Whether to remove linear trend
#         - smooth_window: Optional smoothing window size
#         """
#         data = time_series_data.copy()
#
#         # Remove linear trend if requested
#         if remove_trend:
#             t_numeric = np.arange(len(data))
#             trend_coef = np.polyfit(t_numeric, data['value'], 1)
#             trend = np.polyval(trend_coef, t_numeric)
#             data['value'] = data['value'] - trend
#             data['trend'] = trend
#
#         # Optional smoothing
#         if smooth_window:
#             data['value'] = data['value'].rolling(window=smooth_window, center=True).mean()
#             data = data.dropna()
#
#         return data
#
#     def estimate_frequency_fft(self, time_series_data, max_frequencies=3):
#         """
#         Estimate dominant frequencies using FFT analysis.
#
#         Returns:
#         - frequencies: List of dominant frequencies (cycles per year)
#         - amplitudes: Corresponding amplitude estimates
#         """
#         # Ensure sampling rate is set
#         if self.samples_per_year is None:
#             self._detect_and_set_sampling_rate(time_series_data)
#
#         values = time_series_data['value'].values
#
#         # Perform FFT
#         fft_values = fft(values)
#         fft_freq = fftfreq(len(values), 1/self.samples_per_year)
#
#         # Get magnitude spectrum (positive frequencies only)
#         magnitude = np.abs(fft_values[:len(fft_values)//2])
#         freq_positive = fft_freq[:len(fft_freq)//2]
#
#         # Find peaks in magnitude spectrum
#         peaks, _ = find_peaks(magnitude, height=np.max(magnitude)*0.1)
#
#         # Sort by magnitude and take top frequencies
#         peak_magnitudes = magnitude[peaks]
#         peak_frequencies = freq_positive[peaks]
#
#         # Sort by magnitude (descending)
#         sorted_indices = np.argsort(peak_magnitudes)[::-1]
#
#         frequencies = peak_frequencies[sorted_indices[:max_frequencies]]
#         amplitudes = peak_magnitudes[sorted_indices[:max_frequencies]]
#
#         # Convert amplitudes to reasonable estimates
#         amplitudes = 2 * amplitudes / len(values)
#
#         return frequencies, amplitudes
#
#     def get_adaptive_bounds(self, time_series_data, model_type='auto'):
#         """
#         Generate adaptive parameter bounds based on data characteristics.
#         """
#         values = time_series_data['value'].values
#         dates = time_series_data.index
#         time_span_years = (dates[-1] - dates[0]).days / 365.25
#
#         # Basic statistics
#         value_range = np.ptp(values)  # peak-to-peak
#         value_std = np.std(values)
#         value_mean = np.mean(values)
#
#         if model_type in ['damped', 'auto']:
#             # Bounds for damped sine: [A, tau, f, phi, c]
#             bounds = [
#                 (-value_range*2, value_range*2),      # Amplitude
#                 (0.1, time_span_years*3),             # Decay constant
#                 (0.01, 20),                           # Frequency (cycles/year)
#                 (-2*np.pi, 2*np.pi),                  # Phase
#                 (value_mean-value_std*3, value_mean+value_std*3)  # Offset
#             ]
#         else:  # pure sine
#             # Bounds for pure sine: [A, f, phi, c]
#             bounds = [
#                 (-value_range*2, value_range*2),      # Amplitude
#                 (0.01, 20),                           # Frequency
#                 (-2*np.pi, 2*np.pi),                  # Phase
#                 (value_mean-value_std*3, value_mean+value_std*3)  # Offset
#             ]
#
#         return bounds
#
#     def get_smart_initial_guess(self, time_series_data, model_type='auto'):
#         """
#         Generate intelligent initial parameter guesses using signal analysis.
#         """
#         values = time_series_data['value'].values
#         dates = time_series_data.index
#         time_span_years = (dates[-1] - dates[0]).days / 365.25
#
#         # Estimate frequency using FFT
#         frequencies, amplitudes = self.estimate_frequency_fft(time_series_data, max_frequencies=1)
#
#         if len(frequencies) > 0:
#             freq_guess = frequencies[0]
#             amp_guess = amplitudes[0]
#         else:
#             # Fallback estimates
#             freq_guess = 1.0  # 1 cycle per year
#             amp_guess = np.std(values) * 2
#
#         phase_guess = 0.0
#         offset_guess = np.mean(values)
#
#         if model_type in ['damped', 'auto']:
#             # Check if data shows decay pattern
#             first_half_std = np.std(values[:len(values)//2])
#             second_half_std = np.std(values[len(values)//2:])
#
#             if first_half_std > second_half_std * 1.5:
#                 # Suggests decay
#                 decay_guess = time_span_years / 2
#             else:
#                 # Less obvious decay
#                 decay_guess = time_span_years * 2
#
#             initial_guess = [amp_guess, decay_guess, freq_guess, phase_guess, offset_guess]
#         else:  # pure sine
#             initial_guess = [amp_guess, freq_guess, phase_guess, offset_guess]
#
#         return initial_guess
#
#     def pure_sine_model(self, t, params):
#         """Pure sine wave model: A * sin(2πft + φ) + c"""
#         A, f, phi, c = params
#         return A * np.sin(2 * np.pi * f * t + phi) + c
#
#     def damped_sine_model(self, t, params):
#         """Damped sine wave model: A * exp(-t/τ) * sin(2πft + φ) + c"""
#         A, tau, f, phi, c = params
#         return A * np.exp(-t / tau) * np.sin(2 * np.pi * f * t + phi) + c
#
#     def fit_sine_wave(self, time_series_data, model_type='auto', preprocess=True,
#                      remove_trend=True, n_attempts=3):
#         """
#         Enhanced sine wave fitting with automatic model selection and robust optimization.
#
#         Parameters:
#         - time_series_data: DataFrame with datetime index and 'value' column
#         - model_type: 'pure', 'damped', or 'auto' for automatic selection
#         - preprocess: Whether to preprocess the data
#         - remove_trend: Whether to remove linear trend
#         - n_attempts: Number of optimization attempts with different starting points
#
#         Returns:
#         - fitted_params: Optimized parameters
#         - fitted_signal: Reconstructed signal
#         - fit_metrics: Dictionary with fit quality metrics
#         - model_info: Information about the selected model
#         """
#
#         # Detect and set sampling rate first
#         self._detect_and_set_sampling_rate(time_series_data)
#         print(f"Detected sampling rate: {self.sampling_rate} ({self.samples_per_year:.1f} samples/year)")
#
#         # Preprocess data if requested
#         if preprocess:
#             processed_data = self.preprocess_data(time_series_data, remove_trend=remove_trend)
#         else:
#             processed_data = time_series_data.copy()
#
#         # Prepare time array (convert to years for calculations)
#         t_years = self._convert_to_normalized_time(processed_data)
#         observed_values = processed_data['value'].values
#
#         # Model selection
#         if model_type == 'auto':
#             # Try both models and select the best
#             models_to_try = ['pure', 'damped']
#         else:
#             models_to_try = [model_type]
#
#         best_result = None
#         best_score = -np.inf
#
#         for current_model in models_to_try:
#             print(f"Trying {current_model} sine model...")
#
#             # Get model-specific bounds and initial guess
#             bounds = self.get_adaptive_bounds(processed_data, current_model)
#
#             best_attempt_result = None
#             best_attempt_score = -np.inf
#
#             # Multiple optimization attempts
#             for attempt in range(n_attempts):
#                 try:
#                     # Get initial guess (add some randomness for multiple attempts)
#                     if attempt == 0:
#                         initial_guess = self.get_smart_initial_guess(processed_data, current_model)
#                     else:
#                         # Add random perturbation to initial guess
#                         base_guess = self.get_smart_initial_guess(processed_data, current_model)
#                         perturbation = [np.random.uniform(0.5, 1.5) for _ in base_guess]
#                         initial_guess = [b * p for b, p in zip(base_guess, perturbation)]
#
#                     # Optimization
#                     if current_model == 'damped':
#                         def objective(params):
#                             predicted = self.damped_sine_model(t_years, params)
#                             return np.sum((observed_values - predicted)**2)
#                         model_func = self.damped_sine_model
#                     else:  # pure
#                         def objective(params):
#                             predicted = self.pure_sine_model(t_years, params)
#                             return np.sum((observed_values - predicted)**2)
#                         model_func = self.pure_sine_model
#
#                     result = differential_evolution(
#                         objective,
#                         bounds,
#                         seed=42 + attempt,
#                         maxiter=1000,
#                         atol=1e-8,
#                         tol=1e-8
#                     )
#
#                     if result.success:
#                         fitted_params = result.x
#                         fitted_signal = model_func(t_years, fitted_params)
#
#                         # Calculate metrics
#                         r2 = r2_score(observed_values, fitted_signal)
#                         rmse = np.sqrt(np.mean((observed_values - fitted_signal)**2))
#                         aic = len(observed_values) * np.log(np.mean((observed_values - fitted_signal)**2)) + 2 * len(fitted_params)
#
#                         # Use R² as the primary score for model selection
#                         score = r2
#
#                         if score > best_attempt_score:
#                             best_attempt_score = score
#                             best_attempt_result = {
#                                 'params': fitted_params,
#                                 'signal': fitted_signal,
#                                 'r2': r2,
#                                 'rmse': rmse,
#                                 'aic': aic,
#                                 'model': current_model,
#                                 'model_func': model_func
#                             }
#
#                 except Exception as e:
#                     print(f"Attempt {attempt + 1} failed: {e}")
#                     continue
#
#             # Check if this model is better than previous ones
#             if best_attempt_result and best_attempt_score > best_score:
#                 best_score = best_attempt_score
#                 best_result = best_attempt_result
#
#         if best_result is None:
#             raise ValueError("All fitting attempts failed. Try adjusting the data or parameters.")
#
#         # Store results
#         self.fitted_params = best_result['params']
#         self.fitted_signal = best_result['signal']
#         self.model_type = best_result['model']
#         self.fit_metrics = {
#             'R²': best_result['r2'],
#             'RMSE': best_result['rmse'],
#             'AIC': best_result['aic']
#         }
#
#         # Model information
#         model_info = {
#             'type': best_result['model'],
#             'n_parameters': len(best_result['params']),
#             'parameter_names': self._get_parameter_names(best_result['model'])
#         }
#
#         return self.fitted_params, self.fitted_signal, self.fit_metrics, model_info
#
#     def _get_parameter_names(self, model_type):
#         """Get parameter names for different model types."""
#         if model_type == 'damped':
#             return ['Amplitude', 'Decay_constant', 'Frequency', 'Phase', 'Offset']
#         else:  # pure
#             return ['Amplitude', 'Frequency', 'Phase', 'Offset']
#
#     def print_results(self):
#         """Print fitting results in a formatted way with appropriate units."""
#         if self.fitted_params is None:
#             print("No fitting results available. Run fit_sine_wave() first.")
#             return
#
#         print(f"\n{'='*50}")
#         print(f"SINE WAVE FITTING RESULTS")
#         print(f"{'='*50}")
#         print(f"Model type: {self.model_type}")
#         print(f"Sampling rate: {self.sampling_rate} ({self.samples_per_year:.1f} samples/year)")
#         print(f"\nFitted Parameters:")
#
#         param_names = self._get_parameter_names(self.model_type)
#         for name, value in zip(param_names, self.fitted_params):
#             if 'Frequency' in name:
#                 # Show frequency in multiple units for clarity
#                 cycles_per_year = value
#                 if self.sampling_rate == 'hourly':
#                     cycles_per_hour = value / (365.25 * 24)
#                     cycles_per_day = value / 365.25
#                     print(f"{name}: {cycles_per_year:.4f} cycles/year ({cycles_per_day:.4f} cycles/day, {cycles_per_hour:.6f} cycles/hour)")
#                 elif self.sampling_rate == 'daily':
#                     cycles_per_day = value / 365.25
#                     print(f"{name}: {cycles_per_year:.4f} cycles/year ({cycles_per_day:.4f} cycles/day)")
#                 elif self.sampling_rate == 'weekly':
#                     cycles_per_week = value / 52.18
#                     print(f"{name}: {cycles_per_year:.4f} cycles/year ({cycles_per_week:.4f} cycles/week)")
#                 elif self.sampling_rate == 'monthly':
#                     cycles_per_month = value / 12
#                     print(f"{name}: {cycles_per_year:.4f} cycles/year ({cycles_per_month:.4f} cycles/month)")
#                 else:
#                     print(f"{name}: {cycles_per_year:.4f} cycles/year")
#             elif 'Phase' in name:
#                 print(f"{name}: {value:.4f} radians ({np.degrees(value):.1f}°)")
#             elif 'Decay_constant' in name:
#                 print(f"{name}: {value:.4f} years ({value*365.25:.1f} days)")
#             else:
#                 print(f"{name}: {value:.4f}")
#
#         print(f"\nFit Quality Metrics:")
#         for metric, value in self.fit_metrics.items():
#             print(f"{metric}: {value:.4f}")
#
#     def plot_results(self, original_data, title="Sine Wave Analysis"):
#         """Enhanced plotting with residuals and frequency spectrum."""
#         if self.fitted_signal is None:
#             print("No fitting results to plot. Run fit_sine_wave() first.")
#             return None
#
#         fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
#
#         # Main plot
#         ax1.plot(original_data.index, original_data['value'], 'k-',
#                 label='Original Data', alpha=0.7, linewidth=1)
#         ax1.plot(original_data.index, self.fitted_signal, 'r-',
#                 label=f'Fitted {self.model_type.title()} Model', linewidth=2)
#         ax1.set_ylabel('Value')
#         ax1.set_title(f'{title} (R² = {self.fit_metrics["R²"]:.4f})')
#         ax1.legend()
#         ax1.grid(True, alpha=0.3)
#
#         # Residuals
#         residuals = original_data['value'].values - self.fitted_signal
#         ax2.plot(original_data.index, residuals, 'b-', alpha=0.7)
#         ax2.axhline(y=0, color='k', linestyle='--', alpha=0.5)
#         ax2.set_ylabel('Residuals')
#         ax2.set_xlabel('Date')
#         ax2.set_title(f'Residuals (RMSE = {self.fit_metrics["RMSE"]:.4f})')
#         ax2.grid(True, alpha=0.3)
#
#         # Frequency spectrum of original data
#         frequencies, amplitudes = self.estimate_frequency_fft(original_data, max_frequencies=10)
#         ax3.stem(frequencies, amplitudes, basefmt=" ")
#         ax3.set_xlabel('Frequency (cycles/year)')
#         ax3.set_ylabel('Amplitude')
#         ax3.set_title('Frequency Spectrum')
#         ax3.grid(True, alpha=0.3)
#
#         # Residuals histogram
#         ax4.hist(residuals, bins=20, alpha=0.7, edgecolor='black')
#         ax4.axvline(x=0, color='r', linestyle='--', alpha=0.7)
#         ax4.set_xlabel('Residual Value')
#         ax4.set_ylabel('Frequency')
#         ax4.set_title('Residuals Distribution')
#         ax4.grid(True, alpha=0.3)
#
#         plt.tight_layout()
#         return fig
#
# # Example usage and testing
# # Example usage and testing
# def test_with_different_sampling_rates():
#     """Example of how to specify different sampling rates."""
#
#     # Method 1: Automatic detection (recommended)
#     fitter_auto = SineWaveFitter(sampling_rate='auto')
#
#     # Method 2: Specify predefined sampling rates
#     fitter_hourly = SineWaveFitter(sampling_rate='hourly')
#     fitter_daily = SineWaveFitter(sampling_rate='daily')
#     fitter_weekly = SineWaveFitter(sampling_rate='weekly')
#     fitter_monthly = SineWaveFitter(sampling_rate='monthly')
#     fitter_yearly = SineWaveFitter(sampling_rate='yearly')
#
#     # Method 3: Custom sampling rate (samples per year)
#     fitter_custom = SineWaveFitter(sampling_rate=24*365.25)  # hourly data
#
#     # Example with hourly data
#     print("Example: Hourly temperature data")
#     dates = pd.date_range('2023-01-01', '2023-01-31', freq='H')
#     # Simulate daily temperature cycle + noise
#     hours_from_start = (dates - dates[0]).total_seconds() / 3600
#     temp_data = 20 + 5 * np.sin(2 * np.pi * hours_from_start / 24) + np.random.normal(0, 0.5, len(dates))
#     hourly_df = pd.DataFrame({'value': temp_data}, index=dates)
#
#     # Fit with automatic detection
#     params, signal, metrics, info = fitter_auto.fit_sine_wave(hourly_df)
#     fitter_auto.print_results()
#
#     # Example with monthly economic data
#     print("\n" + "="*60)
#     print("Example: Monthly economic indicator")
#     dates = pd.date_range('2020-01-01', '2024-01-01', freq='MS')  # Month start
#     months_from_start = np.arange(len(dates))
#     # Simulate annual cycle + trend + noise
#     econ_data = 100 + 2 * months_from_start + 10 * np.sin(2 * np.pi * months_from_start / 12) + np.random.normal(0, 2, len(dates))
#     monthly_df = pd.DataFrame({'value': econ_data}, index=dates)
#
#     fitter_monthly = SineWaveFitter(sampling_rate='monthly')
#     params, signal, metrics, info = fitter_monthly.fit_sine_wave(monthly_df)
#     fitter_monthly.print_results()
#
#     return fitter_auto, fitter_monthly, hourly_df, monthly_df
#
# def test_with_real_data():
#     """Example of how to use the enhanced fitter with various data types."""
#
#     # Initialize the fitter with auto-detection
#     fitter = SineWaveFitter(sampling_rate='auto')
#
#     # Example 1: Pure sine wave (daily data)
#     print("Example 1: Pure sine wave (daily data)")
#     dates = pd.date_range('2020-01-01', '2023-12-31', freq='D')
#     t_years = (dates - dates[0]).days / 365.25
#     pure_sine_data = 3 * np.sin(2 * np.pi * 2.5 * t_years + np.pi/3) + 1 + np.random.normal(0, 0.3, len(dates))
#     pure_df = pd.DataFrame({'value': pure_sine_data}, index=dates)
#
#     # Fit the data
#     params, signal, metrics, info = fitter.fit_sine_wave(pure_df, model_type='auto')
#     fitter.print_results()
#
#     # Example 2: Damped sine wave (weekly data)
#     print("\n" + "="*60)
#     print("Example 2: Damped sine wave (weekly data)")
#     dates = pd.date_range('2020-01-01', '2023-12-31', freq='W')
#     t_years = (dates - dates[0]).days / 365.25
#     damped_data = 5 * np.exp(-t_years/1.5) * np.sin(2 * np.pi * 1.2 * t_years) + np.random.normal(0, 0.2, len(dates))
#     damped_df = pd.DataFrame({'value': damped_data}, index=dates)
#
#     fitter_2 = SineWaveFitter(sampling_rate='weekly')
#     params, signal, metrics, info = fitter_2.fit_sine_wave(damped_df, model_type='auto')
#     fitter_2.print_results()
#
#     return fitter, fitter_2, pure_df, damped_df
#
# if __name__ == "__main__":
#     # Run tests
#     fitter1, fitter2, data1, data2 = test_with_real_data()
#
#     # Plot results
#     fig1 = fitter1.plot_results(data1, "Pure Sine Wave Analysis")
#     fig2 = fitter2.plot_results(data2, "Damped Sine Wave Analysis")
#     plt.show()

# %% [raw]
# from scipy.optimize import differential_evolution
# from scipy.fft import fft, fftfreq
# from sklearn.metrics import r2_score
#
# def read_excel_data(filepath, date_column=None, value_column=None):
#     """
#     Read CSV file and prepare for sine wave fitting.
#
#     Parameters:
#     - filepath: Path to CSV file
#     - date_column: Name of date column (if None, uses index)
#     - value_column: Name of value column (if None, uses first numeric column)
#
#     Returns:
#     - DataFrame with datetime index and 'value' column
#     """
#     df = pd.read_excel(filepath)
#
#     if date_column:
#         df[date_column] = pd.to_datetime(df[date_column])
#         df = df.set_index(date_column)
#     else:
#         df.index = pd.to_datetime(df.index)
#
#     if value_column:
#         df = df[[value_column]].rename(columns={value_column: 'value'})
#     else:
#         # Use first numeric column
#         numeric_cols = df.select_dtypes(include=[np.number]).columns
#         df = df[[numeric_cols[0]]].rename(columns={numeric_cols[0]: 'value'})
#
#     return df
#
# def estimate_initial_params(data, sampling_rate='auto'):
#     """Estimate initial parameters from data."""
#     values = data['value'].values
#     dates = data.index
#     t_years = (dates - dates[0]).days / 365.25
#
#     # Basic estimates
#     amplitude = np.std(values) * 2
#     offset = np.mean(values)
#     decay = np.ptp(t_years) / 2
#
#     # Determine sampling rate
#     if sampling_rate == 'auto':
#         dt_days = (dates[1] - dates[0]).days
#         samples_per_year = 365.25 / dt_days
#     elif sampling_rate == 'hourly':
#         samples_per_year = 365.25 * 24
#     elif sampling_rate == 'daily':
#         samples_per_year = 365.25
#     elif sampling_rate == 'weekly':
#         samples_per_year = 52.18
#     elif sampling_rate == 'monthly':
#         samples_per_year = 12
#     elif sampling_rate == 'yearly':
#         samples_per_year = 1
#     else:
#         samples_per_year = sampling_rate  # Custom number
#
#     # FFT for frequency
#     fft_vals = fft(values)
#     freqs = fftfreq(len(values), 1/samples_per_year)
#     magnitude = np.abs(fft_vals[:len(fft_vals)//2])
#     freq_pos = freqs[:len(freqs)//2]
#
#     if len(freq_pos) > 1:
#         peak_idx = np.argmax(magnitude[1:]) + 1  # Skip DC component
#         frequency = freq_pos[peak_idx]
#     else:
#         frequency = 1.0
#
#     return [amplitude, decay, frequency, 0.0, offset]
#
# def damped_sine_model(t, params):
#     """Damped sine model: A * exp(-t/τ) * sin(2πft + φ) + c"""
#     A, tau, f, phi, c = params
#     return A * np.exp(-t / tau) * np.sin(2 * np.pi * f * t + phi) + c
#
# def fit_damped_sine(data, sampling_rate='auto'):
#     """
#     Fit damped sine wave to data.
#
#     Parameters:
#     - data: DataFrame with datetime index and 'value' column
#     - sampling_rate: 'auto', 'hourly', 'daily', 'weekly', 'monthly', 'yearly', or number
#
#     Returns:
#     - params: [amplitude, decay_constant, frequency, phase, offset]
#     - fitted_signal: Array of fitted values
#     - metrics: Dict with R² and RMSE
#     """
#     # Prepare data
#     t_years = (data.index - data.index[0]).days / 365.25
#     values = data['value'].values
#
#     # Initial guess
#     initial_guess = estimate_initial_params(data, sampling_rate)
#
#     # Parameter bounds: [A, tau, f, phi, c]
#     value_range = np.ptp(values)
#     time_span = np.ptp(t_years)
#     bounds = [
#         (-value_range*3, value_range*3),    # Amplitude
#         (0.1, time_span*5),                 # Decay constant
#         (0.01, 20),                         # Frequency
#         (-2*np.pi, 2*np.pi),               # Phase
#         (np.mean(values)-value_range, np.mean(values)+value_range)  # Offset
#     ]
#
#     # Objective function
#     def objective(params):
#         predicted = damped_sine_model(t_years, params)
#         return np.sum((values - predicted)**2)
#
#     # Optimize
#     result = differential_evolution(objective, bounds, seed=42, maxiter=1000)
#
#     if not result.success:
#         raise ValueError("Optimization failed")
#
#     # Calculate fitted signal and metrics
#     fitted_params = result.x
#     fitted_signal = damped_sine_model(t_years, fitted_params)
#
#     r2 = r2_score(values, fitted_signal)
#     rmse = np.sqrt(np.mean((values - fitted_signal)**2))
#
#     metrics = {'R2': r2, 'RMSE': rmse}
#
#     return fitted_params, fitted_signal, metrics
#
# # Example usage
# if __name__ == "__main__":
#     # # Example: Create test data and save to CSV
#     # dates = pd.date_range('2020-01-01', '2023-12-31', freq='D')
#     # t_years = (dates - dates[0]).days / 365.25
#     # test_data = 5 * np.exp(-t_years/2) * np.sin(2*np.pi*1.5*t_years + np.pi/4) + 2 + np.random.normal(0, 0.3, len(dates))
#
#     # test_df = pd.DataFrame({'date': dates, 'value': test_data})
#     # test_df.to_csv('test_data.csv', index=False)
#
#     # Fit the data
#     data = read_excel_data('test_data.xlsx', date_column='time', value_column='residual')
#     params, fitted, metrics = fit_damped_sine(data, sampling_rate='monthly')
#
#     print(f"Fitted parameters:")
#     print(f"Amplitude: {params[0]:.3f}")
#     print(f"Decay constant: {params[1]:.3f} years")
#     print(f"Frequency: {params[2]:.3f} cycles/year")
#     print(f"Phase: {params[3]:.3f} radians")
#     print(f"Offset: {params[4]:.3f}")
#     print(f"R²: {metrics['R2']:.4f}")
#     print(f"RMSE: {metrics['RMSE']:.4f}")
#
#     # Examples of different sampling rates:
#     # params, fitted, metrics = fit_damped_sine(data, sampling_rate='auto')      # Auto-detect
#     # params, fitted, metrics = fit_damped_sine(data, sampling_rate='hourly')    # 24*365.25 samples/year
#     # params, fitted, metrics = fit_damped_sine(data, sampling_rate='weekly')    # 52.18 samples/year
#     # params, fitted, metrics = fit_damped_sine(data, sampling_rate='monthly')   # 12 samples/year
#     # params, fitted, metrics = fit_damped_sine(data, sampling_rate=730.5)       # Custom: twice daily

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
from scipy.fft import fft, fftfreq
from sklearn.metrics import r2_score

# --- Step 1: User-Provided Function for Initial Guesses ---
# This is the function you provided, integrated directly into the script.
# It helps generate a strong starting point for the optimization.

def estimate_initial_params(data, value_column="value"):
    """
    Estimate initial parameters for a single sinusoidal component from data.

    Args:
        data (pd.DataFrame): The input DataFrame with a datetime index.
        value_column (str): The name of the column containing the signal values.

    Returns:
        list: A list of estimated parameters [Amplitude, Decay, Frequency, Phase, Offset].
    """
    values = data[value_column].values
    dates = data.index
    t_years = (dates - dates[0]).total_seconds() / (3600 * 24 * 365.25)

    # Basic estimates
    amplitude = np.std(values) * 2
    offset = np.mean(values)
    decay = np.ptp(t_years) / 2 # Guess decay as half the signal duration

    # Auto-detect sampling rate from the first two data points
    if len(dates) > 1:
        dt_seconds = (dates[1] - dates[0]).total_seconds()
        samples_per_year = (3600 * 24 * 365.25) / dt_seconds
    else:
        samples_per_year = 12 # Default to monthly if only one point

    # Use FFT to find the single strongest frequency
    fft_vals = fft(values - offset) # Remove offset for clearer FFT
    freqs = fftfreq(len(values), 1 / samples_per_year)

    # Find peak frequency in the positive spectrum (ignoring the DC component at index 0)
    positive_freq_indices = np.where(freqs > 0)[0]
    if len(positive_freq_indices) > 0:
        magnitudes = np.abs(fft_vals[positive_freq_indices])
        peak_idx = positive_freq_indices[np.argmax(magnitudes)]
        frequency = freqs[peak_idx]
    else:
        frequency = 1.0 # Fallback frequency

    # Return the list of initial guesses [A, tau, f, phi, c]
    # Phase (phi) is initially set to 0.0
    return [amplitude, decay, frequency, 0.0, offset]


# --- Step 2: Core Model and Fitting Functions (Updated) ---

def multi_damped_sine_model(t, params, num_components):
    """Model for the sum of N damped sine waves."""
    total_signal = 0
    offset = params[-1]
    component_params = np.array(params[:-1]).reshape(num_components, 4)
    for i in range(num_components):
        A, tau, f, phi = component_params[i]
        total_signal += A * np.exp(-t / tau) * np.sin(2 * np.pi * f * t + phi)
    return total_signal + offset

def fit_multi_damped_sine_wave(
    time_series_data,
    num_components=1,
    value_column="value" # NEW: Parameter to specify the value column
):
    """
    Fits a sum of N damped sine waves, now using the new initial guess function.
    """
    dates = time_series_data.index
    t_years = (dates - dates[0]).total_seconds() / (3600 * 24 * 365.25)
    observed_values = time_series_data[value_column].values

    # --- UPDATED INITIAL GUESS LOGIC ---
    initial_guess = []
    bounds = []

    # 1. Use the new function for the first component's guess
    first_guess = estimate_initial_params(time_series_data, value_column)
    initial_guess.extend(first_guess[:4]) # [A, tau, f, phi]
    offset_guess = first_guess[4]         # Get the offset guess

    # 2. For additional components, find other frequency peaks using FFT
    if num_components > 1:
        dt_seconds = (dates[1] - dates[0]).total_seconds()
        samples_per_year = (3600 * 24 * 365.25) / dt_seconds
        yf = fft(observed_values - offset_guess)
        xf = fftfreq(len(observed_values), d=1/samples_per_year)
        # Find the top N frequency peaks
        freq_indices = np.argsort(np.abs(yf[1:len(yf)//2]))[::-1] + 1
        freq_guesses = np.abs(xf[freq_indices[:num_components]])
        
        # Overwrite the first frequency guess for consistency
        initial_guess[2] = freq_guesses[0]
        
        # Add guesses for the other components
        for i in range(1, num_components):
            initial_guess.extend([
                np.std(observed_values)/2, # Guess smaller amplitude for secondary peaks
                t_years[-1],             # Guess a different decay
                freq_guesses[i],         # Use the i-th frequency peak
                0.0
            ])

    # 3. Dynamically create the bounds for all components
    amp_guess, decay_guess, freq_guess = initial_guess[0], initial_guess[1], initial_guess[2]
    bounds.extend([
        (0, amp_guess * 2),
        (0.1, decay_guess * 5),
        (freq_guess * 0.5, freq_guess * 1.5),
        (-np.pi, np.pi)
    ])
    if num_components > 1:
        for i in range(1, num_components):
            amp_g, decay_g, freq_g = initial_guess[i*4], initial_guess[i*4+1], initial_guess[i*4+2]
            bounds.extend([
                (0, amp_g * 3),
                (0.1, decay_g * 5),
                (freq_g * 0.5, freq_g * 1.5),
                (-np.pi, np.pi)
            ])

    # Add the single offset parameter at the end
    initial_guess.append(offset_guess)
    bounds.append((offset_guess - np.std(observed_values), offset_guess + np.std(observed_values)))

    # --- Optimization ---
    def objective(params):
        predicted = multi_damped_sine_model(t_years, params, num_components)
        return np.sum((observed_values - predicted)**2)

    result = differential_evolution(objective, bounds, seed=42, maxiter=2500, tol=1e-7)

    # --- Package and Return Results ---
    fitted_params = result.x
    fitted_signal = multi_damped_sine_model(t_years, fitted_params, num_components)
    r2 = r2_score(observed_values, fitted_signal)
    rmse = np.sqrt(np.mean((observed_values - fitted_signal)**2))
    fit_metrics = {'R²': r2, 'RMSE': rmse}

    return fitted_params, fitted_signal, fit_metrics, t_years


# --- Step 3: Execution with Real Data ---
try:
    print("--- Analysis of test_data_2.csv ---")
    df = pd.read_csv('test_data_2.csv')
    df['time'] = pd.to_datetime(df['time'])
    df = df.set_index('time')

    # The column with the signal is 'residual'. We will pass this to our function.
    VALUE_COLUMN_NAME = 'residual'
    NUM_COMPONENTS = 2

    print(f"Fitting model with {NUM_COMPONENTS} components on column: '{VALUE_COLUMN_NAME}'")

    fitted_params, fitted_signal, metrics, t_years = fit_multi_damped_sine_wave(
        df,
        num_components=NUM_COMPONENTS,
        value_column=VALUE_COLUMN_NAME # Use the new parameter here
    )

    print("\n--- Fit Quality ---")
    print(f"R²: {metrics['R²']:.4f}")
    print(f"RMSE: {metrics['RMSE']:.4f}")

    print("\n--- Fitted Parameters ---")
    component_params = np.array(fitted_params[:-1]).reshape(NUM_COMPONENTS, 4)
    # Sort by frequency for clarity
    component_params = component_params[np.argsort(component_params[:, 2])]

    for i in range(NUM_COMPONENTS):
        A, tau, f, phi = component_params[i]
        period_years = 1/f if f > 0 else float('inf')
        print(f"\n-- Component {i+1} --")
        print(f"  Amplitude (A): {A:.4f}")
        print(f"  Decay (τ):     {tau:.4f} years")
        print(f"  Frequency (f): {f:.4f} cycles/year (Period: {period_years:.2f} years)")
        print(f"  Phase (φ):     {phi:.4f} radians")
    print(f"\nShared Offset (c): {fitted_params[-1]:.4f}")

    # Plotting
    plt.figure(figsize=(14, 7))
    plt.plot(df.index, df[VALUE_COLUMN_NAME], 'k-', label='Original Data', alpha=0.5)
    plt.plot(df.index, fitted_signal, 'r-', label='Total Fitted Model', linewidth=2)
    offset_val = fitted_params[-1]
    for i in range(NUM_COMPONENTS):
        comp_params_with_zero_offset = list(component_params[i]) + [0]
        comp_signal = multi_damped_sine_model(t_years, comp_params_with_zero_offset, 1)
        plt.plot(df.index, comp_signal + offset_val, '--', label=f'Component {i+1}')
    plt.title('Multi-Component Fit Using New Initial Guess Function')
    plt.legend()
    plt.grid(True)
    plt.show()

except FileNotFoundError:
    print("Error: 'test_data_2.csv' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# --- Analysis of test_data_2.csv ---
# Fitting model with 2 components on column: 'residual'
