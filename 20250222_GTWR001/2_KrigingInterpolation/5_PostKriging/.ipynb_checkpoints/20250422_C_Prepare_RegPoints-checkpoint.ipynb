# %%
from appgeopy import *
from my_packages import *

# %% [markdown]
# **2025/4/23**
#
# Chunking the grid point CSV into smaller parts,
#
# The GTWR algorithm has problem wigh large number of points in spatial dimension

# %%
df = pd.read_csv("grid_pnt.csv")
chunk_size = 500
num_chunks = (len(df) + chunk_size - 1) // chunk_size
# Initialize empty list to store our chunks
chunks = []

# Create each chunk using row indexing
for i in range(num_chunks):
    # Calculate starting and ending indices for the current chunk
    start_idx = i * chunk_size
    end_idx = min((i + 1) * chunk_size, len(df))  # Prevent going beyond DataFrame length

    # Extract the chunk and add it to our list
    chunk = df.iloc[start_idx:end_idx].copy()
    chunks.append(chunk)

    print(f"Created chunk {i+1}: rows {start_idx+1}-{end_idx} ({len(chunk)} rows)")

for idx, _df in enumerate(chunks):
    _df.to_csv(
        os.path.join(f"grid_pnt_Chunking/grid_pnt_chunk{str(idx+1).zfill(3)}.csv"), index=False
    )
# Out:
# Created chunk 1: rows 1-1000 (1000 rows)
# Created chunk 2: rows 1001-2000 (1000 rows)
# Created chunk 3: rows 2001-3000 (1000 rows)
# Created chunk 4: rows 3001-4000 (1000 rows)
# Created chunk 5: rows 4001-5000 (1000 rows)
# Created chunk 6: rows 5001-6000 (1000 rows)
# Created chunk 7: rows 6001-7000 (1000 rows)
# Created chunk 8: rows 7001-8000 (1000 rows)
# Created chunk 9: rows 8001-9000 (1000 rows)
# Created chunk 10: rows 9001-10000 (1000 rows)
# Created chunk 11: rows 10001-11000 (1000 rows)
# Created chunk 12: rows 11001-12000 (1000 rows)
# Created chunk 13: rows 12001-13000 (1000 rows)
# Created chunk 14: rows 13001-14000 (1000 rows)
# Created chunk 15: rows 14001-15000 (1000 rows)
# Created chunk 16: rows 15001-16000 (1000 rows)
# Created chunk 17: rows 16001-17000 (1000 rows)
# Created chunk 18: rows 17001-18000 (1000 rows)
# Created chunk 19: rows 18001-19000 (1000 rows)
# Created chunk 20: rows 19001-20000 (1000 rows)
# Created chunk 21: rows 20001-21000 (1000 rows)
# Created chunk 22: rows 21001-22000 (1000 rows)
# Created chunk 23: rows 22001-23000 (1000 rows)
# Created chunk 24: rows 23001-24000 (1000 rows)
# Created chunk 25: rows 24001-25000 (1000 rows)
# Created chunk 26: rows 25001-26000 (1000 rows)
# Created chunk 27: rows 26001-27000 (1000 rows)
# Created chunk 28: rows 27001-28000 (1000 rows)
# Created chunk 29: rows 28001-29000 (1000 rows)
# Created chunk 30: rows 29001-30000 (1000 rows)
# Created chunk 31: rows 30001-31000 (1000 rows)
# Created chunk 32: rows 31001-32000 (1000 rows)
# Created chunk 33: rows 32001-33000 (1000 rows)
# Created chunk 34: rows 33001-34000 (1000 rows)
# Created chunk 35: rows 34001-35000 (1000 rows)
# Created chunk 36: rows 35001-36000 (1000 rows)
# Created chunk 37: rows 36001-37000 (1000 rows)
# Created chunk 38: rows 37001-38000 (1000 rows)
# Created chunk 39: rows 38001-39000 (1000 rows)
# Created chunk 40: rows 39001-40000 (1000 rows)
# Created chunk 41: rows 40001-41000 (1000 rows)
# Created chunk 42: rows 41001-42000 (1000 rows)
# Created chunk 43: rows 42001-43000 (1000 rows)
# Created chunk 44: rows 43001-44000 (1000 rows)
# Created chunk 45: rows 44001-45000 (1000 rows)
# Created chunk 46: rows 45001-46000 (1000 rows)
# Created chunk 47: rows 46001-47000 (1000 rows)
# Created chunk 48: rows 47001-48000 (1000 rows)
# Created chunk 49: rows 48001-49000 (1000 rows)
# Created chunk 50: rows 49001-50000 (1000 rows)
# Created chunk 51: rows 50001-51000 (1000 rows)
# Created chunk 52: rows 51001-52000 (1000 rows)
# Created chunk 53: rows 52001-53000 (1000 rows)
# Created chunk 54: rows 53001-54000 (1000 rows)
# Created chunk 55: rows 54001-55000 (1000 rows)
# Created chunk 56: rows 55001-56000 (1000 rows)
# Created chunk 57: rows 56001-57000 (1000 rows)
# Created chunk 58: rows 57001-58000 (1000 rows)
# Created chunk 59: rows 58001-59000 (1000 rows)
# Created chunk 60: rows 59001-59658 (658 rows)

# %% [markdown]
# **2025/4/21**
#
# Prepare the CSV file which contains coordinates and time, which will be used for regression points

# %%
calibration_points_df = pd.read_csv(
    r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\3_MGTWR\2_Test_Run001\20250416_GWR_InputData_CUMDISP_MLCW_InSAR.csv"
)
calibration_points_df.head(5)
# Out:
#          time    STATION        X_TWD97       Y_TWD97  Layer_1  Layer_2  \
# 0  2016-05-01       ANHE  179539.204623  2.602035e+06    -34.0    -91.0
# 1  2016-05-01    BEICHEN  178859.958807  2.608229e+06     -9.0    -41.0
# 2  2016-05-01     CANLIN  173088.151033  2.608157e+06     -8.0    -55.0
# 3  2016-05-01  DONGGUANG  175783.144962  2.616755e+06    -34.0    -88.0
# 4  2016-05-01      ERLUN  190429.148778  2.629865e+06    -20.0    -24.0
#
#    Layer_3       Layer_4    CUMDISP  All_Layer  monthly
# 0    -13.0 -2.910339e-11 -28.730854     -138.0        0
# 1    -23.0 -6.000000e+00 -33.386893      -79.0        0
# 2    -56.0 -1.700000e+01 -43.787620     -136.0        0
# 3    -94.0 -4.000000e+00 -38.043834     -220.0        0
# 4    -21.0 -5.000000e+00 -22.644068      -70.0        0

# %%
monthly_arr = calibration_points_df["monthly"].unique()
monthly_arr[:5]
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
savefolder = (
    r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\3_MGTWR\6_Test_Run005\regpoints_filefld"
)

grid_point_fld = "grid_pnt_Chunking/"
grid_point_files = glob(os.path.join(grid_point_fld, "*.csv"))

# 2025/4/23: instead of using pd.concat() to combine all into one
# we will save CSV file one by one, corresponding to time period

# 2025/4/23: even chunking like that, the GTWR program cannot extract the points quickly
# I think it depends on the number of points for each time period
# df = pd.read_csv("grid_pnt.csv")

for fname in grid_point_files[:]:
    df = pd.read_csv(fname)
    base = os.path.basename(fname).split(".")[0]

    # output_fld = os.path.join(savefolder, base)
    # os.makedirs(output_fld)

    regression_points_df = pd.DataFrame(data=None, index=None)

    for month in tqdm(monthly_arr, position=1, leave=False):
        df["monthly"] = [month] * len(df)
        # df.to_csv(os.path.join(savefolder, f"regpoint_t{month}.csv"), index=False)
        regression_points_df = pd.concat([regression_points_df, df], ignore_index=True)

    regression_points_df.to_feather(os.path.join(savefolder, f"{base}.feather"))
# Out:
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]

# %% [raw]
# # 2025/04/23 -- remove this, R program cannot read .xz file
# regression_points_df.to_pickle("CRFP_regression_points.xz")

# %% [raw]
# # 2025/04/23 -- remove, we will not export a big file,
# # instead, we export CSV files corresponding to each time period
# regression_points_df.to_feather("CRFP_regression_points.feather")

# %% [raw]
# regression_points_df = pd.DataFrame(data=None, index=None)
#
# for month in tqdm(monthly_arr):
#     temp = df.iloc[:5, :].copy()
#     temp["monthly"] = [month]*5
#     regression_points_df = pd.concat([regression_points_df, temp], ignore_index=True)
#
# regression_points_df.to_csv("regression_points_testting.csv", index=False)

# %% [markdown]
# **2025/4/22**
#
# Reduce regression points size

# %% [raw]
# df = pd.read_csv("grid_pnt.csv")
#
# calibration_points_df = pd.read_csv(r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\3_MGTWR\2_Test_Run001\20250416_GWR_InputData_CUMDISP_MLCW_InSAR.csv")
#
# monthly_arr = calibration_points_df["monthly"].unique()
#
# regression_points_df = pd.DataFrame(data=None, index=None)
#
# for month in tqdm(monthly_arr):
#     df["monthly"] = [month]*len(df)
#     temp = df.iloc[::50, :].copy()
#     regression_points_df = pd.concat([regression_points_df, temp], ignore_index=True)

# %% [raw]
# regression_points_df.to_feather("CRFP_regression_points_reduced50.feather")

# %% [raw]
# pd.read_feather(r"D:\1000_SCRIPTS\003_Project002\20250222_GTWR001\3_MGTWR\4_Test_Run003\regpoints_filefld\grid_pnt_chunk001.feather").query("monthly==0")
