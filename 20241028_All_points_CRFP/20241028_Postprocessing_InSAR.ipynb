# %% [markdown]
# produce the InSAR results for full-image
#
# Yi-Hsien requirements

# %%
from my_packages import *
from appgeopy import *

# %%
fpath = r"D:\SENTINEL_1A_SAR_IMAGES\030_REPROCESS_CHOUSHUI_P2\CALIBRATION_PROCESS\Calibrated_Files\VERT_mm\geodata_CALIBRATED_CUMDISP_VERT_mm_Aug2023_v001.pkl"

gdf = pd.read_pickle(fpath, compression='zip')

# %%
gdf.to_parquet(r'D:\SENTINEL_1A_SAR_IMAGES\030_REPROCESS_CHOUSHUI_P2\CALIBRATION_PROCESS\Calibrated_Files\VERT_mm\geodata_CALIBRATED_CUMDISP_VERT_mm.parquet')

# %% [raw]
# gdf.to_feather("D:\SENTINEL_1A_SAR_IMAGES\030_REPROCESS_CHOUSHUI_P2\CALIBRATION_PROCESS\Calibrated_Files\VERT_mm\geodata_CALIBRATED_CUMDISP_VERT_mm.feather")
